# %%
import pandas
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

from scipy import stats
def r2(x, y):
    return stats.pearsonr(x, y)[0] ** 2

# %%
der_scores = dict(
    alien=739.9, 
    amidar=188.6,
    assault=431.2,
    asterix=470.8,
    bank_heist=51.0,
    battle_zone=10124.6,
    boxing=0.2,
    breakout=1.9, 
    chopper_command=861.8,
    crazy_climber=16185.3,
    demon_attack=508, 
    freeway=27.9, 
    frostbite=866.8,
    gopher=349.5, 
    hero=6857.0, 
    jamesbond=301.6,
    kangaroo=779.3,
    krull=2851.5,
    kung_fu_master=14346.1,
    ms_pacman=1204.1, 
    pong=-19.3,
    private_eye=97.8,
    qbert=1152.9,
    road_runner=9600.0,
    seaquest=354.1, 
    up_n_down=2877.4,
)

random_scores = dict(
    alien=227.8,
    amidar=5.8,
    assault=222.4,
    asterix=210.0,
    bank_heist=14.2,
    battle_zone=2360,
    boxing=0.1,
    breakout=1.7, 
    chopper_command=811.0,
    crazy_climber=10780.5, 
    demon_attack=152.1,
    freeway=0.0, 
    frostbite=65.2,
    gopher=257.6, 
    hero=1027.0, 
    jamesbond=29.0,
    kangaroo=52.0,
    krull=1598.0,
    kung_fu_master=258.5,
    ms_pacman=307.3, 
    pong=-20.7,
    private_eye=24.9,
    qbert=163.9,
    road_runner=11.5, 
    seaquest=68.4,
    up_n_down=533.4
)

curl_scores = dict(
    alien=1148.2,
    amidar=232.3,
    assault=543.7,
    asterix=524.3,
    bank_heist=193.7,
    battle_zone=11208.0,
    boxing=4.8,
    breakout=18.2, 
    chopper_command=1198.0,
    crazy_climber=27805.6, 
    demon_attack=834.0,
    freeway=27.9, 
    frostbite=924.0,
    gopher=801.4, 
    hero=6235.1, 
    jamesbond=400.1,
    kangaroo=345.3,
    krull=3833.6,
    kung_fu_master=14280.0,
    ms_pacman=1492.8, 
    pong=2.1,
    private_eye=105.2,
    qbert=1225.6,
    road_runner=6786.7, 
    seaquest=408.0,
    up_n_down=2735.2
)


human_scores = dict(
    alien=7127.7,
    amidar=1719.5,
    assault=742,
    asterix=8503.3,
    bank_heist=753.1,
    battle_zone=37187.5,
    boxing=12.1,
    breakout=30.5,
    chopper_command=7387.8,
    crazy_climber=35829.4,
    demon_attack=1971,
    freeway=29.6,
    frostbite=4334.7,
    gopher=2412.5,
    hero=30826.4,
    jamesbond=302.8,
    kangaroo=3035.0, 
    krull=2665.5, 
    kung_fu_master=22736.3,
    ms_pacman=6951.6,
    pong=14.6,
    private_eye=69571.3,
    qbert=13455.0, 
    road_runner=7845.0,
    seaquest=42054.7,
    up_n_down=11693.2
)


nature_scores = dict(
    alien=3069, amidar=739.5, assault=3359,
    asterix=6012, bank_heist=429.7, battle_zone=26300.,
    boxing=71.8, breakout=401.2, chopper_command=6687.,
    crazy_climber=114103, demon_attack=9711., freeway=30.3,
    frostbite=328.3, gopher=8520., hero=19950., jamesbond=576.7,
    kangaroo=6740., krull=3805., kung_fu_master=23270.,
    ms_pacman=2311., pong=18.9, private_eye=1788.,
    qbert=10596., road_runner=18257., seaquest=5286., up_n_down=8456.
)

ilya_scores = dict([
 ['alien', 761.4339839039528],
 ['amidar', 97.27108214038698],
 ['assault', 489.0723402551533],
 ['asterix', 637.4622709981793],
 ['bank_heist', 196.57212118002022],
 ['battle_zone', 13520.618932259886],
 ['boxing', 6.865714285714286],
 ['breakout', 14.517297825886795],
 ['chopper_command', 646.5952380952382],
 ['crazy_climber', 19694.06343491709],
 ['demon_attack', 1222.1726236854836],
 ['freeway', 15.406451612903222],
 ['frostbite', 449.6546661390856],
 ['gopher', 598.3884550163659],
 ['hero', 4001.6417938101877],
 ['jamesbond', 272.33614614912597],
 ['kangaroo', 1052.3677908693933],
 ['krull', 4002.30714259636],
 ['kung_fu_master', 7106.436288099127],
 ['ms_pacman', 1065.5951100912523],
 ['pong', -11.374356103459368],
 ['private_eye', 49.17872340425532],
 ['qbert', 1100.9153082502767],
 ['road_runner', 8069.789540523381],
 ['seaquest', 321.8232367384383],
 ['up_n_down', 3924.879963371488]])

def to_df(score_dict):
    df = pandas.DataFrame(np.array(list(score_dict.values())).reshape(-1, 1),
                                     index=list(score_dict.keys()),
                                     columns=["GameScoreAverage"])
    return df

atari_der_scores = to_df(der_scores)
atari_human_scores = to_df(human_scores)
atari_random_scores = to_df(random_scores)
atari_nature_scores = to_df(nature_scores)
atari_ilya_scores = to_df(ilya_scores)
atari_curl_scores = to_df(curl_scores)


atari_nature_scores["game"] = list(nature_scores.keys())
atari_der_scores["game"] = list(der_scores.keys())
atari_human_scores["game"] = list(human_scores.keys())
atari_random_scores["game"] = list(random_scores.keys())
atari_ilya_scores["game"] = list(ilya_scores.keys())
atari_curl_scores["game"] = list(curl_scores.keys())

# %%
def split_on_fields(df, fields=["n_step", "encoder", "tag",
                                 "batch_size", "replay_ratio",
                                 "batch_t", "jumps", "nce",
                                 "use_all_targets", "time_contrastive",
                                 "model_rl_weight", "detach_model"],
                   min_len=0):
    strings = [""]
    dfs = [df]
    
    for field in fields:
        new_dfs = []
        new_strs = []
        for df, string in zip(dfs, strings):
            if len(set(df[field].astype(str))) == 1:
                new_dfs.append(df)
                new_strs.append(string)
            else:
                for value in set(df[field].astype(str)):
                    new_str = string + "-{}: {}-".format(field, value)
                    new_df = df[np.array([str(x) == str(value) for x in df[field]])]
                    if len(new_df) > min_len:
                        new_dfs.append(new_df)
                        new_strs.append(new_str)
    
                    
        dfs = new_dfs
        strings = new_strs
        
    return dfs, strings

# %%
def mean_pairwise_score(df1, df2):
    s1 = (df1["GameScoreAverage"] - atari_random_scores["GameScoreAverage"])/\
          (df2["GameScoreAverage"] - atari_random_scores["GameScoreAverage"])
    s2 = (df2["GameScoreAverage"] - atari_random_scores["GameScoreAverage"])/\
          (df1["GameScoreAverage"] - atari_random_scores["GameScoreAverage"])
    score = (s1.mean() - s2.mean())
    return score

def median_pairwise_score(df1, df2):
    s1 = (df1["GameScoreAverage"] - atari_random_scores["GameScoreAverage"])/\
          (df2["GameScoreAverage"] - atari_random_scores["GameScoreAverage"])
    s2 = (df2["GameScoreAverage"] - atari_random_scores["GameScoreAverage"])/\
          (df1["GameScoreAverage"] - atari_random_scores["GameScoreAverage"])
    return (s1.median() - s2.median())

def group_dfs(dfs):
    proc_dfs = []
    for df in dfs:
        if "seed" in df.keys():
            proc_dfs.append(df.groupby(["seed", "game"]).mean().groupby("game").mean())
        else:
            proc_dfs.append(df.groupby("game").mean())
            
    return proc_dfs

def compare_dfs(dfs, names):
    games = set(dfs[0].game)
    for df in dfs[1:]:
        games = games & set(df.game)
    
    games_dfs = group_dfs(dfs)
    
    games_dfs = [df[[g in games for g in df.index]] for df in games_dfs]
    for df in games_dfs:
        gsn = []
        for game, score in zip(df.index, df["GameScoreAverage"]):
            gsn.append((score - random_scores[game])/(human_scores[game] - random_scores[game]))

        df["GameScoreNormalized"] = np.array(gsn)
    
    for df in games_dfs:
        gsn = []
        for game, score in zip(df.index, df["GameScoreAverage"]):
            gsn.append((score - random_scores[game])/(nature_scores[game] - random_scores[game]))

        df["GameScoreNatureNormalized"] = np.array(gsn)
    
#     print()
#     print("Nature Scores:")
#     for df, name in zip(games_dfs, names):
#         print("{0}: Median: {1:.3f}, Mean: {2:.3f}".format(name, df["GameScoreNatureNormalized"].median(), df["GameScoreNatureNormalized"].mean()))
        
    print()    
    print("Human Scores:")
    for df, name in zip(games_dfs, names):
        print("{0}: Median: {1:.3f}, Mean: {2:.3f}".format(name, df["GameScoreNormalized"].median(), df["GameScoreNormalized"].mean()))
    
    print()
    print("Comparison over {} games:".format(len(games)))
    for i in range(len(dfs)):
        print()
        for j in range(len(dfs)):
            if i == j:
                continue
            better_games = np.sum(games_dfs[i]["GameScoreAverage"] > games_dfs[j]["GameScoreAverage"])
            mean_comp_score = mean_pairwise_score(games_dfs[i], games_dfs[j])
            median_comp_score = median_pairwise_score(games_dfs[i], games_dfs[j])
            
            print("{} above {}: {}, {:.3f}, {:.3f}".format(names[i], names[j],
                                                           better_games, 
                                                           median_comp_score,
                                                          mean_comp_score))
            
    return games_dfs

def sort_games(game_df, key="GameScoreNormalized"):
    indices = np.argsort(game_df[key])
    games_dfs[-1][key][indices]
    for i, game in enumerate(indices):
        i = i+1
        median = (i == len(game_df)//2 or i == len(game_df)//2+1)
        print("{} {} : {:.3f} {:.3f} {}".format(i, 
                                                game_df.index[game],
                                                game_df[key][game],
                                                game_df["GameScoreAverage"][game],
                                                "median" if median else ""))

# %%
tui_1_base = pandas.read_csv("wandb_3232_tui_1.csv")
uat_tui1_no_dueling_c51 = pandas.read_csv("uat_tui1_c51_no_aug.csv")
hn_1_base = pandas.read_csv("wandb_hn1_base.csv")
df = pandas.read_csv("wandb_100k_v3.csv")

# %%
fixed_jat_gl = pandas.read_csv("uat_fixed.csv")
no_noisy_5k = pandas.read_csv("no_noisy_5k_eps.csv")
new_base = pandas.read_csv("wandb_new_base.csv")
new_base_3232 = pandas.read_csv("new_base_3232.csv")
uat_no_noisy = pandas.read_csv("uat_no_noisy.csv")
base_nt_dueling = pandas.read_csv("base_nt_dueling.csv")

# %%
byol_j1_g = pandas.read_csv("byol_j1_g.csv")
byol_sweeps = pandas.read_csv("byol_sweeps.csv")
byol_sweeps, byol_names = split_on_fields(byol_sweeps, ["tag"])

# %%
our_drq = pandas.read_csv("drq_initial_results.csv")
our_drq_nd = our_drq[(our_drq["dueling"] == 0) &
                   (our_drq["distributional"] != 0)]
our_drq_d = our_drq[(our_drq["dueling"] == 1) &
                   (our_drq["distributional"] != 0)]
our_drq_dqn = our_drq[(our_drq["dueling"] == 1) &
                   (our_drq["distributional"] == 0)]
our_drq_512_no_pri = pandas.read_csv("drq_512_no_pri.csv")
our_drq_256_nonoops = pandas.read_csv("drq_256_nonoops.csv")

# %%
uat_aug = pandas.read_csv("g_uat_aug.csv")
uat_aug_ln = uat_aug[uat_aug["norm_type"] == "ln"]
uat_aug_bn = uat_aug[uat_aug["norm_type"] == "bn"]
nce_aug = pandas.read_csv("wandb_drq_nce.csv")

# %%
nce_no_dist = pandas.read_csv("nce1_no_dist.csv")
nce_no_dist_pri = nce_no_dist[nce_no_dist["prioritized_replay"] == 1]
nce_no_dist_no_pri = nce_no_dist[nce_no_dist["prioritized_replay"] == 0]

# %%
controls = df[df["n_step"] == 10]
controls = controls[controls["nce"] == 1]
controls = controls[controls["encoder"] == "nature"]
controls = controls[controls["User"] == "ankeshanand"]
controls = controls[controls["batch_size"] == 32]
controls = controls[controls["tag"].astype(str) == "nan"]

our_der = df[df["n_step"] == 10]
our_der = our_der[our_der["nce"] == 0]
our_der = our_der[our_der["encoder"] == "nature"]
our_der = our_der[our_der["User"] == "ankeshanand"]
our_der = our_der[our_der["batch_size"] == 32]
our_der = our_der[our_der["tag"].astype(str) == "nan"]


jat_1_gl = df[(df["n_step"] == 10) & 
         (df["nce"] == 1) & 
         (df["encoder"] == "nature") &
         (df["User"] == "maxa-schwarzer") &
         (df["batch_size"] == 32) &
         (df["time_contrastive"] == 0) &
         (df["global_nce"] == 0) &
         (df["model_rl_weight"] == 0) &
         (df["jumps"] == 5) &
         (df["use_all_targets"] == 1)]

# %%
names =  ["Base",
          "New Base 32/32",
          "Base w/o target", 
          "Base NT dueling",
          "Base w/ hard negs",
          "Base no-dist Pri 64/32",
          "Base no-dist NoPri 64/32",
          "Base no-dist Pri Aug",
          "BYOL J1 G NoAug",
          *byol_names,
          "UAT", 
          "uat_tui1_no_dueling_c51",
          "UAT no-dist pri aug",
#           "UAT aug DQN LN T1",
          "5k-eps-no-target",
          "der", 
#           "nature",
          "our_der",
          "curl",
          "our drq c51 no dueling",
          "our drq c51 dueling",
          "our drq dqn dueling no-dist",
          "our drq 512 no pri",
          "our drq 256 no noops",
          "drq",
             ]
dfs = [new_base,
       new_base_3232,
       tui_1_base,
       base_nt_dueling,
       hn_1_base, 
       nce_no_dist_pri,
       nce_no_dist_no_pri,
       nce_aug,
       byol_j1_g,
       *byol_sweeps,
#        jat_1_gl,
       fixed_jat_gl,
       uat_tui1_no_dueling_c51,
       uat_aug_bn,
       no_noisy_5k,
       atari_der_scores, 
#        atari_nature_scores,
       our_der,
       atari_curl_scores,
       our_drq_nd,
       our_drq_d,
       our_drq_dqn,
       our_drq_512_no_pri,
       our_drq_256_nonoops,
       atari_ilya_scores,
                         ]
games_dfs = compare_dfs(dfs, names)
# Out:
# Human Scores:
# Base: Median: 0.243, Mean: 0.308
# New Base 32/32: Median: 0.120, Mean: 0.327
# Base w/o target: Median: 0.159, Mean: 0.389
# Base NT dueling: Median: 0.165, Mean: 0.351
# Base w/ hard negs: Median: 0.180, Mean: 0.420
# Base no-dist Pri 64/32: Median: 0.186, Mean: 0.274
# Base no-dist NoPri 64/32: Median: 0.198, Mean: 0.303
# Base no-dist Pri Aug: Median: 0.097, Mean: 0.431
# BYOL J1 G NoAug: Median: 0.217, Mean: 0.257
# -tag: byol_l_j5_aug_no_t0-: Median: 0.246, Mean: 0.480
# -tag: byol_l_j5_aug-: Median: 0.128, Mean: 0.316
# -tag: byol_l_j5_no_t0-: Median: 0.273, Mean: 0.290
# UAT: Median: 0.237, Mean: 0.329
# uat_tui1_no_dueling_c51: Median: 0.168, Mean: 0.297
# UAT no-dist pri aug: Median: 0.205, Mean: 0.467
# 5k-eps-no-target: Median: 0.170, Mean: 0.318
# der: Median: 0.161, Mean: 0.285
# our_der: Median: 0.193, Mean: 0.229
# curl: Median: 0.248, Mean: 0.431
# our drq c51 no dueling: Median: 0.096, Mean: 0.409
# our drq c51 dueling: Median: 0.117, Mean: 0.385
# our drq dqn dueling no-dist: Median: 0.161, Mean: 0.424
# our drq 512 no pri: Median: 0.147, Mean: 0.370
# our drq 256 no noops: Median: 0.153, Mean: 0.381
# drq: Median: 0.284, Mean: 0.370
#
# Comparison over 26 games:
#
# Base above New Base 32/32: 15, 0.300, 0.372
# Base above Base w/o target: 13, 0.044, 1.101
# Base above Base NT dueling: 16, 0.293, 0.451
# Base above Base w/ hard negs: 14, 0.204, 0.130
# Base above Base no-dist Pri 64/32: 19, 0.448, 0.710
# Base above Base no-dist NoPri 64/32: 18, 0.362, 0.616
# Base above Base no-dist Pri Aug: 15, 0.172, 0.721
# Base above BYOL J1 G NoAug: 18, 0.408, 0.114
# Base above -tag: byol_l_j5_aug_no_t0-: 9, -0.357, -1.088
# Base above -tag: byol_l_j5_aug-: 15, 0.046, -4.644
# Base above -tag: byol_l_j5_no_t0-: 14, 0.183, -0.158
# Base above UAT: 11, -0.028, 0.641
# Base above uat_tui1_no_dueling_c51: 14, 0.124, 0.507
# Base above UAT no-dist pri aug: 9, -0.172, -0.221
# Base above 5k-eps-no-target: 17, 0.181, 0.369
# Base above der: 14, 0.214, 3.496
# Base above our_der: 19, 0.585, 1.036
# Base above curl: 7, -1.014, -0.838
# Base above our drq c51 no dueling: 13, -0.042, 1.482
# Base above our drq c51 dueling: 11, -0.102, 0.257
# Base above our drq dqn dueling no-dist: 11, -0.160, -0.233
# Base above our drq 512 no pri: 11, -0.131, 0.011
# Base above our drq 256 no noops: 10, -0.246, 12.785
# Base above drq: 11, -0.200, -0.571
#
# New Base 32/32 above Base: 11, -0.300, -0.372
# New Base 32/32 above Base w/o target: 13, 0.098, 0.132
# New Base 32/32 above Base NT dueling: 11, -0.100, -0.879
# New Base 32/32 above Base w/ hard negs: 11, -0.176, -0.182
# New Base 32/32 above Base no-dist Pri 64/32: 17, 0.303, 0.562
# New Base 32/32 above Base no-dist NoPri 64/32: 13, -0.005, 0.184
# New Base 32/32 above Base no-dist Pri Aug: 12, -0.130, 0.243
# New Base 32/32 above BYOL J1 G NoAug: 17, 0.525, 1.336
# New Base 32/32 above -tag: byol_l_j5_aug_no_t0-: 5, -0.876, -1.313
# New Base 32/32 above -tag: byol_l_j5_aug-: 17, 0.232, -1.898
# New Base 32/32 above -tag: byol_l_j5_no_t0-: 12, -0.251, -0.705
# New Base 32/32 above UAT: 9, -0.297, 0.010
# New Base 32/32 above uat_tui1_no_dueling_c51: 13, -0.131, 0.340
# New Base 32/32 above UAT no-dist pri aug: 11, -0.382, -0.599
# New Base 32/32 above 5k-eps-no-target: 11, -0.074, 0.179
# New Base 32/32 above der: 13, -0.030, 5.010
# New Base 32/32 above our_der: 18, 0.557, 1.252
# New Base 32/32 above curl: 4, -0.728, -1.555
# New Base 32/32 above our drq c51 no dueling: 12, -0.270, 0.405
# New Base 32/32 above our drq c51 dueling: 14, 0.047, -0.210
# New Base 32/32 above our drq dqn dueling no-dist: 8, -0.079, -0.510
# New Base 32/32 above our drq 512 no pri: 15, 0.211, 0.333
# New Base 32/32 above our drq 256 no noops: 11, -0.450, 5.506
# New Base 32/32 above drq: 13, -0.073, -0.678
#
# Base w/o target above Base: 13, -0.044, -1.101
# Base w/o target above New Base 32/32: 13, -0.098, -0.132
# Base w/o target above Base NT dueling: 13, -0.068, -1.669
# Base w/o target above Base w/ hard negs: 13, -0.021, -0.374
# Base w/o target above Base no-dist Pri 64/32: 16, 0.455, 0.022
# Base w/o target above Base no-dist NoPri 64/32: 14, -0.076, -0.414
# Base w/o target above Base no-dist Pri Aug: 14, 0.222, -0.443
# Base w/o target above BYOL J1 G NoAug: 15, 0.126, 1.285
# Base w/o target above -tag: byol_l_j5_aug_no_t0-: 8, -0.434, -3.257
# Base w/o target above -tag: byol_l_j5_aug-: 18, 0.197, -5.806
# Base w/o target above -tag: byol_l_j5_no_t0-: 11, -0.454, -1.254
# Base w/o target above UAT: 10, -0.222, -0.180
# Base w/o target above uat_tui1_no_dueling_c51: 15, 0.138, -0.475
# Base w/o target above UAT no-dist pri aug: 11, -0.279, -1.303
# Base w/o target above 5k-eps-no-target: 16, 0.113, -0.375
# Base w/o target above der: 16, 0.312, 2.992
# Base w/o target above our_der: 16, 0.177, 0.565
# Base w/o target above curl: 9, -0.349, -3.730
# Base w/o target above our drq c51 no dueling: 12, -0.201, -0.048
# Base w/o target above our drq c51 dueling: 11, -0.107, -1.807
# Base w/o target above our drq dqn dueling no-dist: 10, -0.260, -1.684
# Base w/o target above our drq 512 no pri: 14, 0.143, -0.769
# Base w/o target above our drq 256 no noops: 14, 0.093, 10.949
# Base w/o target above drq: 13, -0.009, -2.495
#
# Base NT dueling above Base: 10, -0.293, -0.451
# Base NT dueling above New Base 32/32: 15, 0.100, 0.879
# Base NT dueling above Base w/o target: 13, 0.068, 1.669
# Base NT dueling above Base w/ hard negs: 10, -0.154, 0.985
# Base NT dueling above Base no-dist Pri 64/32: 16, 0.160, 1.048
# Base NT dueling above Base no-dist NoPri 64/32: 15, 0.051, 0.149
# Base NT dueling above Base no-dist Pri Aug: 11, -0.079, 1.212
# Base NT dueling above BYOL J1 G NoAug: 13, 0.143, 0.444
# Base NT dueling above -tag: byol_l_j5_aug_no_t0-: 6, -0.586, -3.498
# Base NT dueling above -tag: byol_l_j5_aug-: 15, 0.186, -5.884
# Base NT dueling above -tag: byol_l_j5_no_t0-: 9, -0.308, 1.055
# Base NT dueling above UAT: 10, -0.258, 0.720
# Base NT dueling above uat_tui1_no_dueling_c51: 14, 0.111, 1.626
# Base NT dueling above UAT no-dist pri aug: 10, -0.398, -0.178
# Base NT dueling above 5k-eps-no-target: 15, 0.125, 1.415
# Base NT dueling above der: 12, 0.036, 5.773
# Base NT dueling above our_der: 18, 0.567, 3.620
# Base NT dueling above curl: 5, -0.605, 0.164
# Base NT dueling above our drq c51 no dueling: 10, -0.323, 1.420
# Base NT dueling above our drq c51 dueling: 9, -0.137, 0.408
# Base NT dueling above our drq dqn dueling no-dist: 7, -0.299, -0.347
# Base NT dueling above our drq 512 no pri: 13, -0.059, 0.102
# Base NT dueling above our drq 256 no noops: 10, -0.237, -5.926
# Base NT dueling above drq: 13, -0.059, -0.683
#
# Base w/ hard negs above Base: 12, -0.204, -0.130
# Base w/ hard negs above New Base 32/32: 15, 0.176, 0.182
# Base w/ hard negs above Base w/o target: 13, 0.021, 0.374
# Base w/ hard negs above Base NT dueling: 16, 0.154, -0.985
# Base w/ hard negs above Base no-dist Pri 64/32: 19, 0.438, 0.591
# Base w/ hard negs above Base no-dist NoPri 64/32: 17, 0.224, 0.297
# Base w/ hard negs above Base no-dist Pri Aug: 15, 0.076, 0.585
# Base w/ hard negs above BYOL J1 G NoAug: 13, 0.024, 2.708
# Base w/ hard negs above -tag: byol_l_j5_aug_no_t0-: 10, -0.394, -1.228
# Base w/ hard negs above -tag: byol_l_j5_aug-: 16, 0.242, -4.694
# Base w/ hard negs above -tag: byol_l_j5_no_t0-: 10, -0.327, -0.237
# Base w/ hard negs above UAT: 13, 0.020, 0.495
# Base w/ hard negs above uat_tui1_no_dueling_c51: 16, 0.233, 0.377
# Base w/ hard negs above UAT no-dist pri aug: 11, -0.272, -0.274
# Base w/ hard negs above 5k-eps-no-target: 18, 0.160, 0.171
# Base w/ hard negs above der: 12, -0.080, 10.389
# Base w/ hard negs above our_der: 16, 0.370, 2.414
# Base w/ hard negs above curl: 7, -0.539, -1.584
# Base w/ hard negs above our drq c51 no dueling: 12, -0.240, 0.714
# Base w/ hard negs above our drq c51 dueling: 12, -0.134, 0.333
# Base w/ hard negs above our drq dqn dueling no-dist: 12, -0.091, -0.237
# Base w/ hard negs above our drq 512 no pri: 15, 0.095, 0.662
# Base w/ hard negs above our drq 256 no noops: 14, 0.022, 9.653
# Base w/ hard negs above drq: 15, 0.058, -1.180
#
# Base no-dist Pri 64/32 above Base: 7, -0.448, -0.710
# Base no-dist Pri 64/32 above New Base 32/32: 9, -0.303, -0.562
# Base no-dist Pri 64/32 above Base w/o target: 10, -0.455, -0.022
# Base no-dist Pri 64/32 above Base NT dueling: 10, -0.160, -1.048
# Base no-dist Pri 64/32 above Base w/ hard negs: 7, -0.438, -0.591
# Base no-dist Pri 64/32 above Base no-dist NoPri 64/32: 13, -0.111, -0.389
# Base no-dist Pri 64/32 above Base no-dist Pri Aug: 9, -0.366, -0.121
# Base no-dist Pri 64/32 above BYOL J1 G NoAug: 12, -0.076, 0.271
# Base no-dist Pri 64/32 above -tag: byol_l_j5_aug_no_t0-: 6, -0.738, -2.533
# Base no-dist Pri 64/32 above -tag: byol_l_j5_aug-: 13, -0.060, -3.780
# Base no-dist Pri 64/32 above -tag: byol_l_j5_no_t0-: 7, -0.321, -0.745
# Base no-dist Pri 64/32 above UAT: 7, -0.563, -1.062
# Base no-dist Pri 64/32 above uat_tui1_no_dueling_c51: 11, -0.299, -0.331
# Base no-dist Pri 64/32 above UAT no-dist pri aug: 8, -0.562, -1.624
# Base no-dist Pri 64/32 above 5k-eps-no-target: 9, -0.396, -0.216
# Base no-dist Pri 64/32 above der: 9, -0.420, 1.895
# Base no-dist Pri 64/32 above our_der: 14, 0.111, 0.286
# Base no-dist Pri 64/32 above curl: 3, -1.109, -3.071
# Base no-dist Pri 64/32 above our drq c51 no dueling: 9, -0.558, 0.640
# Base no-dist Pri 64/32 above our drq c51 dueling: 8, -0.283, -0.777
# Base no-dist Pri 64/32 above our drq dqn dueling no-dist: 7, -0.514, -1.334
# Base no-dist Pri 64/32 above our drq 512 no pri: 10, -0.185, -0.240
# Base no-dist Pri 64/32 above our drq 256 no noops: 8, -0.787, -5.161
# Base no-dist Pri 64/32 above drq: 8, -0.334, -3.308
#
# Base no-dist NoPri 64/32 above Base: 8, -0.362, -0.616
# Base no-dist NoPri 64/32 above New Base 32/32: 13, 0.005, -0.184
# Base no-dist NoPri 64/32 above Base w/o target: 12, 0.076, 0.414
# Base no-dist NoPri 64/32 above Base NT dueling: 11, -0.051, -0.149
# Base no-dist NoPri 64/32 above Base w/ hard negs: 9, -0.224, -0.297
# Base no-dist NoPri 64/32 above Base no-dist Pri 64/32: 13, 0.111, 0.389
# Base no-dist NoPri 64/32 above Base no-dist Pri Aug: 9, -0.178, -0.040
# Base no-dist NoPri 64/32 above BYOL J1 G NoAug: 14, 0.240, -0.518
# Base no-dist NoPri 64/32 above -tag: byol_l_j5_aug_no_t0-: 6, -0.437, -3.538
# Base no-dist NoPri 64/32 above -tag: byol_l_j5_aug-: 16, 0.298, -4.773
# Base no-dist NoPri 64/32 above -tag: byol_l_j5_no_t0-: 9, -0.345, -0.231
# Base no-dist NoPri 64/32 above UAT: 6, -0.495, -0.813
# Base no-dist NoPri 64/32 above uat_tui1_no_dueling_c51: 8, -0.205, 0.550
# Base no-dist NoPri 64/32 above UAT no-dist pri aug: 10, -0.273, -1.664
# Base no-dist NoPri 64/32 above 5k-eps-no-target: 12, -0.025, 0.489
# Base no-dist NoPri 64/32 above der: 12, 0.109, 1.396
# Base no-dist NoPri 64/32 above our_der: 14, 0.235, 1.373
# Base no-dist NoPri 64/32 above curl: 6, -1.065, -2.579
# Base no-dist NoPri 64/32 above our drq c51 no dueling: 12, -0.149, -0.233
# Base no-dist NoPri 64/32 above our drq c51 dueling: 10, -0.209, -1.068
# Base no-dist NoPri 64/32 above our drq dqn dueling no-dist: 9, -0.264, -1.389
# Base no-dist NoPri 64/32 above our drq 512 no pri: 10, -0.099, -0.663
# Base no-dist NoPri 64/32 above our drq 256 no noops: 10, -0.185, -13.461
# Base no-dist NoPri 64/32 above drq: 8, -0.239, -3.116
#
# Base no-dist Pri Aug above Base: 11, -0.172, -0.721
# Base no-dist Pri Aug above New Base 32/32: 14, 0.130, -0.243
# Base no-dist Pri Aug above Base w/o target: 12, -0.222, 0.443
# Base no-dist Pri Aug above Base NT dueling: 15, 0.079, -1.212
# Base no-dist Pri Aug above Base w/ hard negs: 11, -0.076, -0.585
# Base no-dist Pri Aug above Base no-dist Pri 64/32: 17, 0.366, 0.121
# Base no-dist Pri Aug above Base no-dist NoPri 64/32: 17, 0.178, 0.040
# Base no-dist Pri Aug above BYOL J1 G NoAug: 16, 0.470, 1.247
# Base no-dist Pri Aug above -tag: byol_l_j5_aug_no_t0-: 9, -0.430, -1.478
# Base no-dist Pri Aug above -tag: byol_l_j5_aug-: 17, 0.224, -3.455
# Base no-dist Pri Aug above -tag: byol_l_j5_no_t0-: 12, -0.028, -1.448
# Base no-dist Pri Aug above UAT: 12, -0.105, -0.451
# Base no-dist Pri Aug above uat_tui1_no_dueling_c51: 16, 0.258, 0.060
# Base no-dist Pri Aug above UAT no-dist pri aug: 9, -0.304, -0.749
# Base no-dist Pri Aug above 5k-eps-no-target: 15, 0.211, -0.033
# Base no-dist Pri Aug above der: 10, -0.179, 8.800
# Base no-dist Pri Aug above our_der: 18, 0.468, 1.524
# Base no-dist Pri Aug above curl: 7, -0.889, -2.195
# Base no-dist Pri Aug above our drq c51 no dueling: 12, -0.237, -0.231
# Base no-dist Pri Aug above our drq c51 dueling: 12, -0.131, -0.343
# Base no-dist Pri Aug above our drq dqn dueling no-dist: 9, -0.338, -0.653
# Base no-dist Pri Aug above our drq 512 no pri: 11, -0.181, 0.612
# Base no-dist Pri Aug above our drq 256 no noops: 14, 0.056, 2.133
# Base no-dist Pri Aug above drq: 11, -0.223, -0.901
#
# BYOL J1 G NoAug above Base: 8, -0.408, -0.114
# BYOL J1 G NoAug above New Base 32/32: 9, -0.525, -1.336
# BYOL J1 G NoAug above Base w/o target: 11, -0.126, -1.285
# BYOL J1 G NoAug above Base NT dueling: 13, -0.143, -0.444
# BYOL J1 G NoAug above Base w/ hard negs: 13, -0.024, -2.708
# BYOL J1 G NoAug above Base no-dist Pri 64/32: 14, 0.076, -0.271
# BYOL J1 G NoAug above Base no-dist NoPri 64/32: 12, -0.240, 0.518
# BYOL J1 G NoAug above Base no-dist Pri Aug: 10, -0.470, -1.247
# BYOL J1 G NoAug above -tag: byol_l_j5_aug_no_t0-: 7, -0.759, 0.770
# BYOL J1 G NoAug above -tag: byol_l_j5_aug-: 14, -0.080, -1.720
# BYOL J1 G NoAug above -tag: byol_l_j5_no_t0-: 8, -0.526, -2.320
# BYOL J1 G NoAug above UAT: 9, -0.504, -1.660
# BYOL J1 G NoAug above uat_tui1_no_dueling_c51: 11, -0.167, -1.388
# BYOL J1 G NoAug above UAT no-dist pri aug: 8, -0.464, -2.603
# BYOL J1 G NoAug above 5k-eps-no-target: 11, -0.248, -1.374
# BYOL J1 G NoAug above der: 11, -0.221, 0.730
# BYOL J1 G NoAug above our_der: 19, 0.231, -2.105
# BYOL J1 G NoAug above curl: 7, -1.463, -3.199
# BYOL J1 G NoAug above our drq c51 no dueling: 11, -0.455, -0.940
# BYOL J1 G NoAug above our drq c51 dueling: 6, -0.435, -1.297
# BYOL J1 G NoAug above our drq dqn dueling no-dist: 6, -0.634, -1.331
# BYOL J1 G NoAug above our drq 512 no pri: 10, -0.404, -0.046
# BYOL J1 G NoAug above our drq 256 no noops: 11, -0.717, 4.518
# BYOL J1 G NoAug above drq: 9, -0.565, -1.417
#
# -tag: byol_l_j5_aug_no_t0- above Base: 17, 0.357, 1.088
# -tag: byol_l_j5_aug_no_t0- above New Base 32/32: 21, 0.876, 1.313
# -tag: byol_l_j5_aug_no_t0- above Base w/o target: 18, 0.434, 3.257
# -tag: byol_l_j5_aug_no_t0- above Base NT dueling: 20, 0.586, 3.498
# -tag: byol_l_j5_aug_no_t0- above Base w/ hard negs: 16, 0.394, 1.228
# -tag: byol_l_j5_aug_no_t0- above Base no-dist Pri 64/32: 20, 0.738, 2.533
# -tag: byol_l_j5_aug_no_t0- above Base no-dist NoPri 64/32: 20, 0.437, 3.538
# -tag: byol_l_j5_aug_no_t0- above Base no-dist Pri Aug: 17, 0.430, 1.478
# -tag: byol_l_j5_aug_no_t0- above BYOL J1 G NoAug: 19, 0.759, -0.770
# -tag: byol_l_j5_aug_no_t0- above -tag: byol_l_j5_aug-: 23, 0.806, -2.208
# -tag: byol_l_j5_aug_no_t0- above -tag: byol_l_j5_no_t0-: 15, 0.394, 0.620
# -tag: byol_l_j5_aug_no_t0- above UAT: 15, 0.241, 1.623
# -tag: byol_l_j5_aug_no_t0- above uat_tui1_no_dueling_c51: 18, 0.369, 1.709
# -tag: byol_l_j5_aug_no_t0- above UAT no-dist pri aug: 17, 0.272, 0.461
# -tag: byol_l_j5_aug_no_t0- above 5k-eps-no-target: 20, 0.483, 1.450
# -tag: byol_l_j5_aug_no_t0- above der: 17, 0.359, 9.702
# -tag: byol_l_j5_aug_no_t0- above our_der: 20, 0.908, 3.234
# -tag: byol_l_j5_aug_no_t0- above curl: 9, -0.343, -0.054
# -tag: byol_l_j5_aug_no_t0- above our drq c51 no dueling: 17, 0.938, 2.338
# -tag: byol_l_j5_aug_no_t0- above our drq c51 dueling: 16, 0.336, 0.600
# -tag: byol_l_j5_aug_no_t0- above our drq dqn dueling no-dist: 15, 0.170, 0.119
# -tag: byol_l_j5_aug_no_t0- above our drq 512 no pri: 17, 0.470, -0.757
# -tag: byol_l_j5_aug_no_t0- above our drq 256 no noops: 15, 0.450, 17.354
# -tag: byol_l_j5_aug_no_t0- above drq: 15, 0.475, 0.057
#
# -tag: byol_l_j5_aug- above Base: 11, -0.046, 4.644
# -tag: byol_l_j5_aug- above New Base 32/32: 9, -0.232, 1.898
# -tag: byol_l_j5_aug- above Base w/o target: 8, -0.197, 5.806
# -tag: byol_l_j5_aug- above Base NT dueling: 11, -0.186, 5.884
# -tag: byol_l_j5_aug- above Base w/ hard negs: 10, -0.242, 4.694
# -tag: byol_l_j5_aug- above Base no-dist Pri 64/32: 13, 0.060, 3.780
# -tag: byol_l_j5_aug- above Base no-dist NoPri 64/32: 10, -0.298, 4.773
# -tag: byol_l_j5_aug- above Base no-dist Pri Aug: 9, -0.224, 3.455
# -tag: byol_l_j5_aug- above BYOL J1 G NoAug: 12, 0.080, 1.720
# -tag: byol_l_j5_aug- above -tag: byol_l_j5_aug_no_t0-: 3, -0.806, 2.208
# -tag: byol_l_j5_aug- above -tag: byol_l_j5_no_t0-: 8, -0.432, 5.265
# -tag: byol_l_j5_aug- above UAT: 8, -0.321, 2.788
# -tag: byol_l_j5_aug- above uat_tui1_no_dueling_c51: 12, -0.118, 3.065
# -tag: byol_l_j5_aug- above UAT no-dist pri aug: 5, -0.612, 1.791
# -tag: byol_l_j5_aug- above 5k-eps-no-target: 12, -0.166, 3.604
# -tag: byol_l_j5_aug- above der: 11, -0.023, 7.247
# -tag: byol_l_j5_aug- above our_der: 14, 0.150, 5.204
# -tag: byol_l_j5_aug- above curl: 6, -0.857, 3.631
# -tag: byol_l_j5_aug- above our drq c51 no dueling: 13, -0.052, -0.883
# -tag: byol_l_j5_aug- above our drq c51 dueling: 10, -0.181, 0.612
# -tag: byol_l_j5_aug- above our drq dqn dueling no-dist: 7, -0.715, 1.591
# -tag: byol_l_j5_aug- above our drq 512 no pri: 10, -0.285, -1.715
# -tag: byol_l_j5_aug- above our drq 256 no noops: 11, -0.047, 2.353
# -tag: byol_l_j5_aug- above drq: 11, -0.395, 3.419
#
# -tag: byol_l_j5_no_t0- above Base: 12, -0.183, 0.158
# -tag: byol_l_j5_no_t0- above New Base 32/32: 14, 0.251, 0.705
# -tag: byol_l_j5_no_t0- above Base w/o target: 15, 0.454, 1.254
# -tag: byol_l_j5_no_t0- above Base NT dueling: 17, 0.308, -1.055
# -tag: byol_l_j5_no_t0- above Base w/ hard negs: 16, 0.327, 0.237
# -tag: byol_l_j5_no_t0- above Base no-dist Pri 64/32: 19, 0.321, 0.745
# -tag: byol_l_j5_no_t0- above Base no-dist NoPri 64/32: 17, 0.345, 0.231
# -tag: byol_l_j5_no_t0- above Base no-dist Pri Aug: 14, 0.028, 1.448
# -tag: byol_l_j5_no_t0- above BYOL J1 G NoAug: 18, 0.526, 2.320
# -tag: byol_l_j5_no_t0- above -tag: byol_l_j5_aug_no_t0-: 11, -0.394, -0.620
# -tag: byol_l_j5_no_t0- above -tag: byol_l_j5_aug-: 18, 0.432, -5.265
# -tag: byol_l_j5_no_t0- above UAT: 12, -0.011, 1.522
# -tag: byol_l_j5_no_t0- above uat_tui1_no_dueling_c51: 16, 0.510, 0.465
# -tag: byol_l_j5_no_t0- above UAT no-dist pri aug: 13, -0.009, 0.345
# -tag: byol_l_j5_no_t0- above 5k-eps-no-target: 15, 0.274, 0.277
# -tag: byol_l_j5_no_t0- above der: 15, 0.116, 4.170
# -tag: byol_l_j5_no_t0- above our_der: 22, 0.599, 0.472
# -tag: byol_l_j5_no_t0- above curl: 8, -0.794, -0.794
# -tag: byol_l_j5_no_t0- above our drq c51 no dueling: 15, 0.233, 2.464
# -tag: byol_l_j5_no_t0- above our drq c51 dueling: 14, 0.234, 1.070
# -tag: byol_l_j5_no_t0- above our drq dqn dueling no-dist: 11, -0.174, 0.354
# -tag: byol_l_j5_no_t0- above our drq 512 no pri: 14, 0.083, 1.149
# -tag: byol_l_j5_no_t0- above our drq 256 no noops: 13, -0.028, 30.048
# -tag: byol_l_j5_no_t0- above drq: 13, -0.043, -0.594
#
# UAT above Base: 15, 0.028, -0.641
# UAT above New Base 32/32: 17, 0.297, -0.010
# UAT above Base w/o target: 16, 0.222, 0.180
# UAT above Base NT dueling: 16, 0.258, -0.720
# UAT above Base w/ hard negs: 13, -0.020, -0.495
# UAT above Base no-dist Pri 64/32: 19, 0.563, 1.062
# UAT above Base no-dist NoPri 64/32: 20, 0.495, 0.813
# UAT above Base no-dist Pri Aug: 14, 0.105, 0.451
# UAT above BYOL J1 G NoAug: 17, 0.504, 1.660
# UAT above -tag: byol_l_j5_aug_no_t0-: 11, -0.241, -1.623
# UAT above -tag: byol_l_j5_aug-: 18, 0.321, -2.788
# UAT above -tag: byol_l_j5_no_t0-: 13, 0.011, -1.522
# UAT above uat_tui1_no_dueling_c51: 18, 0.099, 0.911
# UAT above UAT no-dist pri aug: 11, -0.118, -0.527
# UAT above 5k-eps-no-target: 16, 0.241, 0.587
# UAT above der: 13, -0.036, 3.173
# UAT above our_der: 19, 0.546, 1.017
# UAT above curl: 6, -0.943, -2.193
# UAT above our drq c51 no dueling: 14, 0.045, 0.867
# UAT above our drq c51 dueling: 15, 0.166, -0.372
# UAT above our drq dqn dueling no-dist: 13, -0.039, -0.285
# UAT above our drq 512 no pri: 16, 0.379, 1.343
# UAT above our drq 256 no noops: 12, -0.076, 1.385
# UAT above drq: 15, 0.143, 0.044
#
# uat_tui1_no_dueling_c51 above Base: 12, -0.124, -0.507
# uat_tui1_no_dueling_c51 above New Base 32/32: 13, 0.131, -0.340
# uat_tui1_no_dueling_c51 above Base w/o target: 11, -0.138, 0.475
# uat_tui1_no_dueling_c51 above Base NT dueling: 12, -0.111, -1.626
# uat_tui1_no_dueling_c51 above Base w/ hard negs: 10, -0.233, -0.377
# uat_tui1_no_dueling_c51 above Base no-dist Pri 64/32: 15, 0.299, 0.331
# uat_tui1_no_dueling_c51 above Base no-dist NoPri 64/32: 18, 0.205, -0.550
# uat_tui1_no_dueling_c51 above Base no-dist Pri Aug: 10, -0.258, -0.060
# uat_tui1_no_dueling_c51 above BYOL J1 G NoAug: 15, 0.167, 1.388
# uat_tui1_no_dueling_c51 above -tag: byol_l_j5_aug_no_t0-: 8, -0.369, -1.709
# uat_tui1_no_dueling_c51 above -tag: byol_l_j5_aug-: 14, 0.118, -3.065
# uat_tui1_no_dueling_c51 above -tag: byol_l_j5_no_t0-: 10, -0.510, -0.465
# uat_tui1_no_dueling_c51 above UAT: 8, -0.099, -0.911
# uat_tui1_no_dueling_c51 above UAT no-dist pri aug: 10, -0.303, -1.225
# uat_tui1_no_dueling_c51 above 5k-eps-no-target: 13, 0.029, 0.052
# uat_tui1_no_dueling_c51 above der: 9, -0.149, 2.004
# uat_tui1_no_dueling_c51 above our_der: 16, 0.248, 0.657
# uat_tui1_no_dueling_c51 above curl: 6, -0.884, -2.066
# uat_tui1_no_dueling_c51 above our drq c51 no dueling: 11, -0.410, 0.219
# uat_tui1_no_dueling_c51 above our drq c51 dueling: 11, -0.050, 0.078
# uat_tui1_no_dueling_c51 above our drq dqn dueling no-dist: 8, -0.531, -0.656
# uat_tui1_no_dueling_c51 above our drq 512 no pri: 10, -0.096, 0.795
# uat_tui1_no_dueling_c51 above our drq 256 no noops: 9, -0.670, -9.114
# uat_tui1_no_dueling_c51 above drq: 13, -0.153, -2.270
#
# UAT no-dist pri aug above Base: 17, 0.172, 0.221
# UAT no-dist pri aug above New Base 32/32: 15, 0.382, 0.599
# UAT no-dist pri aug above Base w/o target: 15, 0.279, 1.303
# UAT no-dist pri aug above Base NT dueling: 16, 0.398, 0.178
# UAT no-dist pri aug above Base w/ hard negs: 15, 0.272, 0.274
# UAT no-dist pri aug above Base no-dist Pri 64/32: 18, 0.562, 1.624
# UAT no-dist pri aug above Base no-dist NoPri 64/32: 16, 0.273, 1.664
# UAT no-dist pri aug above Base no-dist Pri Aug: 17, 0.304, 0.749
# UAT no-dist pri aug above BYOL J1 G NoAug: 18, 0.464, 2.603
# UAT no-dist pri aug above -tag: byol_l_j5_aug_no_t0-: 9, -0.272, -0.461
# UAT no-dist pri aug above -tag: byol_l_j5_aug-: 21, 0.612, -1.791
# UAT no-dist pri aug above -tag: byol_l_j5_no_t0-: 13, 0.009, -0.345
# UAT no-dist pri aug above UAT: 15, 0.118, 0.527
# UAT no-dist pri aug above uat_tui1_no_dueling_c51: 16, 0.303, 1.225
# UAT no-dist pri aug above 5k-eps-no-target: 15, 0.473, 0.948
# UAT no-dist pri aug above der: 14, 0.207, 13.183
# UAT no-dist pri aug above our_der: 17, 0.625, 3.399
# UAT no-dist pri aug above curl: 8, -0.716, -0.982
# UAT no-dist pri aug above our drq c51 no dueling: 16, 0.293, 1.137
# UAT no-dist pri aug above our drq c51 dueling: 15, 0.159, 0.581
# UAT no-dist pri aug above our drq dqn dueling no-dist: 12, -0.040, 0.126
# UAT no-dist pri aug above our drq 512 no pri: 17, 0.381, 1.133
# UAT no-dist pri aug above our drq 256 no noops: 14, 0.269, 2.407
# UAT no-dist pri aug above drq: 16, 0.092, 0.281
#
# 5k-eps-no-target above Base: 9, -0.181, -0.369
# 5k-eps-no-target above New Base 32/32: 15, 0.074, -0.179
# 5k-eps-no-target above Base w/o target: 10, -0.113, 0.375
# 5k-eps-no-target above Base NT dueling: 11, -0.125, -1.415
# 5k-eps-no-target above Base w/ hard negs: 8, -0.160, -0.171
# 5k-eps-no-target above Base no-dist Pri 64/32: 17, 0.396, 0.216
# 5k-eps-no-target above Base no-dist NoPri 64/32: 14, 0.025, -0.489
# 5k-eps-no-target above Base no-dist Pri Aug: 11, -0.211, 0.033
# 5k-eps-no-target above BYOL J1 G NoAug: 15, 0.248, 1.374
# 5k-eps-no-target above -tag: byol_l_j5_aug_no_t0-: 6, -0.483, -1.450
# 5k-eps-no-target above -tag: byol_l_j5_aug-: 14, 0.166, -3.604
# 5k-eps-no-target above -tag: byol_l_j5_no_t0-: 10, -0.274, -0.277
# 5k-eps-no-target above UAT: 9, -0.241, -0.587
# 5k-eps-no-target above uat_tui1_no_dueling_c51: 13, -0.029, -0.052
# 5k-eps-no-target above UAT no-dist pri aug: 11, -0.473, -0.948
# 5k-eps-no-target above der: 11, -0.077, 3.418
# 5k-eps-no-target above our_der: 16, 0.314, 0.855
# 5k-eps-no-target above curl: 5, -0.718, -1.876
# 5k-eps-no-target above our drq c51 no dueling: 10, -0.441, -0.106
# 5k-eps-no-target above our drq c51 dueling: 12, -0.050, 0.140
# 5k-eps-no-target above our drq dqn dueling no-dist: 8, -0.665, -0.529
# 5k-eps-no-target above our drq 512 no pri: 13, -0.285, 0.558
# 5k-eps-no-target above our drq 256 no noops: 11, -0.516, -4.592
# 5k-eps-no-target above drq: 11, -0.275, -2.142
#
# der above Base: 12, -0.214, -3.496
# der above New Base 32/32: 13, 0.030, -5.010
# der above Base w/o target: 10, -0.312, -2.992
# der above Base NT dueling: 14, -0.036, -5.773
# der above Base w/ hard negs: 14, 0.080, -10.389
# der above Base no-dist Pri 64/32: 17, 0.420, -1.895
# der above Base no-dist NoPri 64/32: 14, -0.109, -1.396
# der above Base no-dist Pri Aug: 16, 0.179, -8.800
# der above BYOL J1 G NoAug: 15, 0.221, -0.730
# der above -tag: byol_l_j5_aug_no_t0-: 9, -0.359, -9.702
# der above -tag: byol_l_j5_aug-: 15, 0.023, -7.247
# der above -tag: byol_l_j5_no_t0-: 11, -0.116, -4.170
# der above UAT: 13, 0.036, -3.173
# der above uat_tui1_no_dueling_c51: 17, 0.149, -2.004
# der above UAT no-dist pri aug: 12, -0.207, -13.183
# der above 5k-eps-no-target: 15, 0.077, -3.418
# der above our_der: 17, 0.306, -1.036
# der above curl: 5, -0.499, -6.581
# der above our drq c51 no dueling: 14, 0.045, -12.883
# der above our drq c51 dueling: 14, 0.086, -11.968
# der above our drq dqn dueling no-dist: 12, -0.114, -8.996
# der above our drq 512 no pri: 14, 0.019, -5.083
# der above our drq 256 no noops: 11, -0.283, -5.653
# der above drq: 12, -0.405, -5.425
#
# our_der above Base: 7, -0.585, -1.036
# our_der above New Base 32/32: 8, -0.557, -1.252
# our_der above Base w/o target: 10, -0.177, -0.565
# our_der above Base NT dueling: 8, -0.567, -3.620
# our_der above Base w/ hard negs: 10, -0.370, -2.414
# our_der above Base no-dist Pri 64/32: 12, -0.111, -0.286
# our_der above Base no-dist NoPri 64/32: 12, -0.235, -1.373
# our_der above Base no-dist Pri Aug: 8, -0.468, -1.524
# our_der above BYOL J1 G NoAug: 7, -0.231, 2.105
# our_der above -tag: byol_l_j5_aug_no_t0-: 6, -0.908, -3.234
# our_der above -tag: byol_l_j5_aug-: 12, -0.150, -5.204
# our_der above -tag: byol_l_j5_no_t0-: 4, -0.599, -0.472
# our_der above UAT: 7, -0.546, -1.017
# our_der above uat_tui1_no_dueling_c51: 10, -0.248, -0.657
# our_der above UAT no-dist pri aug: 9, -0.625, -3.399
# our_der above 5k-eps-no-target: 10, -0.314, -0.855
# our_der above der: 9, -0.306, 1.036
# our_der above curl: 6, -1.232, -2.492
# our_der above our drq c51 no dueling: 11, -0.365, -2.091
# our_der above our drq c51 dueling: 7, -0.270, -1.891
# our_der above our drq dqn dueling no-dist: 8, -0.797, -1.522
# our_der above our drq 512 no pri: 10, -0.615, 0.257
# our_der above our drq 256 no noops: 9, -0.808, -3.852
# our_der above drq: 8, -0.517, -3.363
#
# curl above Base: 19, 1.014, 0.838
# curl above New Base 32/32: 22, 0.728, 1.555
# curl above Base w/o target: 17, 0.349, 3.730
# curl above Base NT dueling: 21, 0.605, -0.164
# curl above Base w/ hard negs: 19, 0.539, 1.584
# curl above Base no-dist Pri 64/32: 23, 1.109, 3.071
# curl above Base no-dist NoPri 64/32: 20, 1.065, 2.579
# curl above Base no-dist Pri Aug: 19, 0.889, 2.195
# curl above BYOL J1 G NoAug: 19, 1.463, 3.199
# curl above -tag: byol_l_j5_aug_no_t0-: 17, 0.343, 0.054
# curl above -tag: byol_l_j5_aug-: 20, 0.857, -3.631
# curl above -tag: byol_l_j5_no_t0-: 18, 0.794, 0.794
# curl above UAT: 20, 0.943, 2.193
# curl above uat_tui1_no_dueling_c51: 20, 0.884, 2.066
# curl above UAT no-dist pri aug: 18, 0.716, 0.982
# curl above 5k-eps-no-target: 21, 0.718, 1.876
# curl above der: 20, 0.499, 6.581
# curl above our_der: 20, 1.232, 2.492
# curl above our drq c51 no dueling: 18, 1.113, 3.700
# curl above our drq c51 dueling: 21, 1.062, 1.457
# curl above our drq dqn dueling no-dist: 18, 0.825, 1.117
# curl above our drq 512 no pri: 20, 0.809, 2.156
# curl above our drq 256 no noops: 19, 0.800, 27.715
# curl above drq: 17, 0.613, 0.411
#
# our drq c51 no dueling above Base: 13, 0.042, -1.482
# our drq c51 no dueling above New Base 32/32: 14, 0.270, -0.405
# our drq c51 no dueling above Base w/o target: 14, 0.201, 0.048
# our drq c51 no dueling above Base NT dueling: 16, 0.323, -1.420
# our drq c51 no dueling above Base w/ hard negs: 14, 0.240, -0.714
# our drq c51 no dueling above Base no-dist Pri 64/32: 17, 0.558, -0.640
# our drq c51 no dueling above Base no-dist NoPri 64/32: 14, 0.149, 0.233
# our drq c51 no dueling above Base no-dist Pri Aug: 14, 0.237, 0.231
# our drq c51 no dueling above BYOL J1 G NoAug: 15, 0.455, 0.940
# our drq c51 no dueling above -tag: byol_l_j5_aug_no_t0-: 9, -0.938, -2.338
# our drq c51 no dueling above -tag: byol_l_j5_aug-: 13, 0.052, 0.883
# our drq c51 no dueling above -tag: byol_l_j5_no_t0-: 10, -0.233, -2.464
# our drq c51 no dueling above UAT: 11, -0.045, -0.867
# our drq c51 no dueling above uat_tui1_no_dueling_c51: 15, 0.410, -0.219
# our drq c51 no dueling above UAT no-dist pri aug: 10, -0.293, -1.137
# our drq c51 no dueling above 5k-eps-no-target: 15, 0.441, 0.106
# our drq c51 no dueling above der: 12, -0.045, 12.883
# our drq c51 no dueling above our_der: 15, 0.365, 2.091
# our drq c51 no dueling above curl: 8, -1.113, -3.700
# our drq c51 no dueling above our drq c51 dueling: 12, -0.145, -0.543
# our drq c51 no dueling above our drq dqn dueling no-dist: 10, -0.445, -0.845
# our drq c51 no dueling above our drq 512 no pri: 11, -0.423, 0.702
# our drq c51 no dueling above our drq 256 no noops: 13, -0.034, 0.276
# our drq c51 no dueling above drq: 13, -0.124, -0.899
#
# our drq c51 dueling above Base: 15, 0.102, -0.257
# our drq c51 dueling above New Base 32/32: 12, -0.047, 0.210
# our drq c51 dueling above Base w/o target: 15, 0.107, 1.807
# our drq c51 dueling above Base NT dueling: 17, 0.137, -0.408
# our drq c51 dueling above Base w/ hard negs: 14, 0.134, -0.333
# our drq c51 dueling above Base no-dist Pri 64/32: 18, 0.283, 0.777
# our drq c51 dueling above Base no-dist NoPri 64/32: 16, 0.209, 1.068
# our drq c51 dueling above Base no-dist Pri Aug: 14, 0.131, 0.343
# our drq c51 dueling above BYOL J1 G NoAug: 20, 0.435, 1.297
# our drq c51 dueling above -tag: byol_l_j5_aug_no_t0-: 10, -0.336, -0.600
# our drq c51 dueling above -tag: byol_l_j5_aug-: 16, 0.181, -0.612
# our drq c51 dueling above -tag: byol_l_j5_no_t0-: 12, -0.234, -1.070
# our drq c51 dueling above UAT: 11, -0.166, 0.372
# our drq c51 dueling above uat_tui1_no_dueling_c51: 15, 0.050, -0.078
# our drq c51 dueling above UAT no-dist pri aug: 11, -0.159, -0.581
# our drq c51 dueling above 5k-eps-no-target: 14, 0.050, -0.140
# our drq c51 dueling above der: 12, -0.086, 11.968
# our drq c51 dueling above our_der: 19, 0.270, 1.891
# our drq c51 dueling above curl: 5, -1.062, -1.457
# our drq c51 dueling above our drq c51 no dueling: 14, 0.145, 0.543
# our drq c51 dueling above our drq dqn dueling no-dist: 12, -0.026, -0.506
# our drq c51 dueling above our drq 512 no pri: 18, 0.217, 0.057
# our drq c51 dueling above our drq 256 no noops: 12, -0.144, 14.505
# our drq c51 dueling above drq: 13, -0.004, -0.929
#
# our drq dqn dueling no-dist above Base: 15, 0.160, 0.233
# our drq dqn dueling no-dist above New Base 32/32: 18, 0.079, 0.510
# our drq dqn dueling no-dist above Base w/o target: 16, 0.260, 1.684
# our drq dqn dueling no-dist above Base NT dueling: 19, 0.299, 0.347
# our drq dqn dueling no-dist above Base w/ hard negs: 14, 0.091, 0.237
# our drq dqn dueling no-dist above Base no-dist Pri 64/32: 19, 0.514, 1.334
# our drq dqn dueling no-dist above Base no-dist NoPri 64/32: 17, 0.264, 1.389
# our drq dqn dueling no-dist above Base no-dist Pri Aug: 17, 0.338, 0.653
# our drq dqn dueling no-dist above BYOL J1 G NoAug: 20, 0.634, 1.331
# our drq dqn dueling no-dist above -tag: byol_l_j5_aug_no_t0-: 11, -0.170, -0.119
# our drq dqn dueling no-dist above -tag: byol_l_j5_aug-: 19, 0.715, -1.591
# our drq dqn dueling no-dist above -tag: byol_l_j5_no_t0-: 15, 0.174, -0.354
# our drq dqn dueling no-dist above UAT: 13, 0.039, 0.285
# our drq dqn dueling no-dist above uat_tui1_no_dueling_c51: 18, 0.531, 0.656
# our drq dqn dueling no-dist above UAT no-dist pri aug: 14, 0.040, -0.126
# our drq dqn dueling no-dist above 5k-eps-no-target: 18, 0.665, 0.529
# our drq dqn dueling no-dist above der: 14, 0.114, 8.996
# our drq dqn dueling no-dist above our_der: 18, 0.797, 1.522
# our drq dqn dueling no-dist above curl: 8, -0.825, -1.117
# our drq dqn dueling no-dist above our drq c51 no dueling: 16, 0.445, 0.845
# our drq dqn dueling no-dist above our drq c51 dueling: 14, 0.026, 0.506
# our drq dqn dueling no-dist above our drq 512 no pri: 18, 0.312, 0.698
# our drq dqn dueling no-dist above our drq 256 no noops: 17, 0.174, 3.530
# our drq dqn dueling no-dist above drq: 17, 0.180, -0.198
#
# our drq 512 no pri above Base: 15, 0.131, -0.011
# our drq 512 no pri above New Base 32/32: 11, -0.211, -0.333
# our drq 512 no pri above Base w/o target: 12, -0.143, 0.769
# our drq 512 no pri above Base NT dueling: 13, 0.059, -0.102
# our drq 512 no pri above Base w/ hard negs: 11, -0.095, -0.662
# our drq 512 no pri above Base no-dist Pri 64/32: 16, 0.185, 0.240
# our drq 512 no pri above Base no-dist NoPri 64/32: 16, 0.099, 0.663
# our drq 512 no pri above Base no-dist Pri Aug: 15, 0.181, -0.612
# our drq 512 no pri above BYOL J1 G NoAug: 16, 0.404, 0.046
# our drq 512 no pri above -tag: byol_l_j5_aug_no_t0-: 9, -0.470, 0.757
# our drq 512 no pri above -tag: byol_l_j5_aug-: 16, 0.285, 1.715
# our drq 512 no pri above -tag: byol_l_j5_no_t0-: 12, -0.083, -1.149
# our drq 512 no pri above UAT: 10, -0.379, -1.343
# our drq 512 no pri above uat_tui1_no_dueling_c51: 16, 0.096, -0.795
# our drq 512 no pri above UAT no-dist pri aug: 9, -0.381, -1.133
# our drq 512 no pri above 5k-eps-no-target: 13, 0.285, -0.558
# our drq 512 no pri above der: 12, -0.019, 5.083
# our drq 512 no pri above our_der: 16, 0.615, -0.257
# our drq 512 no pri above curl: 6, -0.809, -2.156
# our drq 512 no pri above our drq c51 no dueling: 15, 0.423, -0.702
# our drq 512 no pri above our drq c51 dueling: 8, -0.217, -0.057
# our drq 512 no pri above our drq dqn dueling no-dist: 8, -0.312, -0.698
# our drq 512 no pri above our drq 256 no noops: 12, -0.041, -7.042
# our drq 512 no pri above drq: 12, -0.020, -1.295
#
# our drq 256 no noops above Base: 16, 0.246, -12.785
# our drq 256 no noops above New Base 32/32: 15, 0.450, -5.506
# our drq 256 no noops above Base w/o target: 12, -0.093, -10.949
# our drq 256 no noops above Base NT dueling: 16, 0.237, 5.926
# our drq 256 no noops above Base w/ hard negs: 12, -0.022, -9.653
# our drq 256 no noops above Base no-dist Pri 64/32: 18, 0.787, 5.161
# our drq 256 no noops above Base no-dist NoPri 64/32: 16, 0.185, 13.461
# our drq 256 no noops above Base no-dist Pri Aug: 12, -0.056, -2.133
# our drq 256 no noops above BYOL J1 G NoAug: 15, 0.717, -4.518
# our drq 256 no noops above -tag: byol_l_j5_aug_no_t0-: 11, -0.450, -17.354
# our drq 256 no noops above -tag: byol_l_j5_aug-: 15, 0.047, -2.353
# our drq 256 no noops above -tag: byol_l_j5_no_t0-: 13, 0.028, -30.048
# our drq 256 no noops above UAT: 14, 0.076, -1.385
# our drq 256 no noops above uat_tui1_no_dueling_c51: 17, 0.670, 9.114
# our drq 256 no noops above UAT no-dist pri aug: 12, -0.269, -2.407
# our drq 256 no noops above 5k-eps-no-target: 15, 0.516, 4.592
# our drq 256 no noops above der: 15, 0.283, 5.653
# our drq 256 no noops above our_der: 17, 0.808, 3.852
# our drq 256 no noops above curl: 7, -0.800, -27.715
# our drq 256 no noops above our drq c51 no dueling: 13, 0.034, -0.276
# our drq 256 no noops above our drq c51 dueling: 14, 0.144, -14.505
# our drq 256 no noops above our drq dqn dueling no-dist: 9, -0.174, -3.530
# our drq 256 no noops above our drq 512 no pri: 14, 0.041, 7.042
# our drq 256 no noops above drq: 13, -0.007, 9.298
#
# drq above Base: 15, 0.200, 0.571
# drq above New Base 32/32: 13, 0.073, 0.678
# drq above Base w/o target: 13, 0.009, 2.495
# drq above Base NT dueling: 13, 0.059, 0.683
# drq above Base w/ hard negs: 11, -0.058, 1.180
# drq above Base no-dist Pri 64/32: 18, 0.334, 3.308
# drq above Base no-dist NoPri 64/32: 18, 0.239, 3.116
# drq above Base no-dist Pri Aug: 15, 0.223, 0.901
# drq above BYOL J1 G NoAug: 17, 0.565, 1.417
# drq above -tag: byol_l_j5_aug_no_t0-: 11, -0.475, -0.057
# drq above -tag: byol_l_j5_aug-: 15, 0.395, -3.419
# drq above -tag: byol_l_j5_no_t0-: 13, 0.043, 0.594
# drq above UAT: 11, -0.143, -0.044
# drq above uat_tui1_no_dueling_c51: 13, 0.153, 2.270
# drq above UAT no-dist pri aug: 10, -0.092, -0.281
# drq above 5k-eps-no-target: 15, 0.275, 2.142
# drq above der: 14, 0.405, 5.425
# drq above our_der: 18, 0.517, 3.363
# drq above curl: 9, -0.613, -0.411
# drq above our drq c51 no dueling: 13, 0.124, 0.899
# drq above our drq c51 dueling: 13, 0.004, 0.929
# drq above our drq dqn dueling no-dist: 9, -0.180, 0.198
# drq above our drq 512 no pri: 14, 0.020, 1.295
# drq above our drq 256 no noops: 13, 0.007, -9.298

# %%
for game_df, name in zip(games_dfs, names):
    
    print(name)
    sort_games(game_df, "GameScoreNormalized")
    print()
    print()
# Out:
# Base
# 1 private_eye : -0.000 -1.464
# 2 seaquest : 0.005 295.560
# 3 chopper_command : 0.027 986.500
# 4 frostbite : 0.041 238.760
# 5 qbert : 0.049 816.400
# 6 demon_attack : 0.053 248.660
# 7 asterix : 0.060 706.900
# 8 alien : 0.070 711.180
# 9 gopher : 0.073 415.960
# 10 amidar : 0.074 133.310
# 11 ms_pacman : 0.161 1378.660
# 12 hero : 0.217 7490.510
# 13 breakout : 0.222 8.080 median
# 14 battle_zone : 0.264 11566.000 median
# 15 bank_heist : 0.270 213.640
# 16 kangaroo : 0.302 952.800
# 17 crazy_climber : 0.325 18923.000
# 18 pong : 0.346 -8.502
# 19 boxing : 0.380 4.656
# 20 assault : 0.384 421.715
# 21 up_n_down : 0.405 5054.060
# 22 freeway : 0.522 15.445
# 23 kung_fu_master : 0.551 12651.800
# 24 jamesbond : 0.799 247.800
# 25 road_runner : 1.154 9049.000
# 26 krull : 1.250 2932.486
#
#
# Base w/o target
# 1 private_eye : 0.001 93.286
# 2 qbert : 0.003 205.950
# 3 seaquest : 0.004 223.800
# 4 gopher : 0.005 268.160
# 5 chopper_command : 0.029 1003.800
# 6 demon_attack : 0.043 229.750
# 7 asterix : 0.050 622.500
# 8 amidar : 0.061 110.772
# 9 alien : 0.069 707.040
# 10 ms_pacman : 0.088 894.620
# 11 breakout : 0.104 4.708
# 12 bank_heist : 0.130 110.040
# 13 pong : 0.159 -15.082 median
# 14 hero : 0.159 5774.940 median
# 15 frostbite : 0.209 958.680
# 16 kangaroo : 0.254 809.000
# 17 battle_zone : 0.296 12678.000
# 18 crazy_climber : 0.564 24901.400
# 19 up_n_down : 0.574 6936.520
# 20 assault : 0.657 563.888
# 21 boxing : 0.706 8.576
# 22 freeway : 0.758 22.450
# 23 kung_fu_master : 0.796 18153.000
# 24 jamesbond : 1.199 357.300
# 25 road_runner : 1.387 10873.400
# 26 krull : 1.807 3526.806
#
#
# Base NT dueling
# 1 chopper_command : -0.015 713.800
# 2 private_eye : -0.000 22.400
# 3 seaquest : 0.007 380.840
# 4 demon_attack : 0.028 203.490
# 5 qbert : 0.030 557.050
# 6 frostbite : 0.040 236.880
# 7 gopher : 0.050 365.200
# 8 asterix : 0.054 654.100
# 9 amidar : 0.066 119.440
# 10 alien : 0.070 712.520
# 11 ms_pacman : 0.121 1111.300
# 12 hero : 0.129 4881.060
# 13 pong : 0.155 -15.212 median
# 14 breakout : 0.175 6.744 median
# 15 battle_zone : 0.207 9560.000
# 16 bank_heist : 0.225 180.420
# 17 assault : 0.312 384.264
# 18 kangaroo : 0.368 1151.200
# 19 kung_fu_master : 0.452 10409.800
# 20 crazy_climber : 0.464 22407.200
# 21 up_n_down : 0.719 8556.460
# 22 boxing : 0.820 9.944
# 23 freeway : 0.914 27.050
# 24 road_runner : 0.995 7802.200
# 25 jamesbond : 1.070 322.100
# 26 krull : 1.660 3369.712
#
#
# Base w/ hard negs
# 1 private_eye : 0.001 89.000
# 2 seaquest : 0.005 269.680
# 3 qbert : 0.017 389.050
# 4 gopher : 0.020 300.040
# 5 demon_attack : 0.023 193.440
# 6 chopper_command : 0.023 962.750
# 7 asterix : 0.040 541.500
# 8 amidar : 0.067 120.324
# 9 alien : 0.082 792.100
# 10 frostbite : 0.095 471.780
# 11 ms_pacman : 0.117 1084.440
# 12 hero : 0.158 5749.380
# 13 pong : 0.163 -14.932 median
# 14 breakout : 0.196 7.356 median
# 15 kangaroo : 0.235 752.800
# 16 battle_zone : 0.245 10892.000
# 17 bank_heist : 0.397 307.680
# 18 up_n_down : 0.411 5117.520
# 19 assault : 0.455 458.846
# 20 kung_fu_master : 0.589 13499.000
# 21 jamesbond : 0.641 204.400
# 22 crazy_climber : 0.676 27724.400
# 23 freeway : 0.812 24.024
# 24 road_runner : 1.172 9196.000
# 25 boxing : 2.006 24.166
# 26 krull : 2.283 4034.802
#
#
# Base no-dist Pri 64/32
# 1 chopper_command : -0.015 712.800
# 2 private_eye : 0.001 60.206
# 3 seaquest : 0.005 289.280
# 4 demon_attack : 0.009 169.310
# 5 gopher : 0.011 280.240
# 6 qbert : 0.036 645.300
# 7 asterix : 0.048 605.500
# 8 amidar : 0.050 90.672
# 9 alien : 0.070 714.000
# 10 frostbite : 0.083 417.820
# 11 hero : 0.099 3965.760
# 12 ms_pacman : 0.133 1191.600
# 13 bank_heist : 0.167 137.240 median
# 14 battle_zone : 0.205 9484.000 median
# 15 breakout : 0.220 8.038
# 16 boxing : 0.309 3.812
# 17 assault : 0.310 383.250
# 18 freeway : 0.341 10.082
# 19 road_runner : 0.360 2830.000
# 20 up_n_down : 0.371 4678.140
# 21 kangaroo : 0.399 1241.600
# 22 kung_fu_master : 0.409 9444.200
# 23 crazy_climber : 0.481 22819.600
# 24 pong : 0.576 -0.356
# 25 jamesbond : 0.607 195.200
# 26 krull : 1.853 3576.000
#
#
# Base no-dist NoPri 64/32
# 1 chopper_command : -0.032 603.400
# 2 private_eye : -0.000 17.522
# 3 seaquest : 0.004 239.240
# 4 demon_attack : 0.009 168.420
# 5 gopher : 0.011 281.920
# 6 qbert : 0.036 640.200
# 7 asterix : 0.056 676.400
# 8 amidar : 0.061 109.704
# 9 alien : 0.066 685.780
# 10 hero : 0.130 4905.120
# 11 bank_heist : 0.155 128.420
# 12 boxing : 0.171 2.156
# 13 ms_pacman : 0.197 1616.660 median
# 14 breakout : 0.199 7.418 median
# 15 battle_zone : 0.216 9870.000
# 16 pong : 0.222 -12.860
# 17 assault : 0.286 371.070
# 18 frostbite : 0.296 1328.260
# 19 kangaroo : 0.325 1021.200
# 20 up_n_down : 0.364 4599.580
# 21 road_runner : 0.377 2964.400
# 22 freeway : 0.462 13.682
# 23 crazy_climber : 0.658 27267.600
# 24 kung_fu_master : 0.702 16030.600
# 25 jamesbond : 0.869 267.000
# 26 krull : 2.049 3785.592
#
#
# Base no-dist Pri Aug
# 1 private_eye : 0.001 86.600
# 2 seaquest : 0.005 277.800
# 3 chopper_command : 0.007 855.800
# 4 pong : 0.033 -19.548
# 5 qbert : 0.035 629.300
# 6 demon_attack : 0.043 229.950
# 7 asterix : 0.044 576.333
# 8 amidar : 0.064 114.716
# 9 crazy_climber : 0.067 12455.600
# 10 frostbite : 0.067 351.250
# 11 bank_heist : 0.070 65.625
# 12 alien : 0.071 719.960
# 13 gopher : 0.093 457.200 median
# 14 ms_pacman : 0.102 987.460 median
# 15 hero : 0.130 4913.830
# 16 kangaroo : 0.208 673.500
# 17 battle_zone : 0.255 11248.000
# 18 breakout : 0.333 11.292
# 19 up_n_down : 0.396 4947.860
# 20 kung_fu_master : 0.428 9872.000
# 21 assault : 0.473 468.350
# 22 freeway : 0.906 26.823
# 23 road_runner : 1.161 9107.400
# 24 jamesbond : 1.310 387.750
# 25 boxing : 1.580 19.060
# 26 krull : 3.329 5151.878
#
#
# UAT
# 1 private_eye : 0.001 100.000
# 2 chopper_command : 0.002 822.750
# 3 seaquest : 0.005 258.640
# 4 gopher : 0.025 311.520
# 5 qbert : 0.048 802.750
# 6 demon_attack : 0.055 252.990
# 7 asterix : 0.063 729.900
# 8 alien : 0.077 758.480
# 9 amidar : 0.082 145.760
# 10 frostbite : 0.097 479.580
# 11 ms_pacman : 0.107 1016.460
# 12 battle_zone : 0.182 8708.000
# 13 hero : 0.218 7533.270 median
# 14 boxing : 0.255 3.158 median
# 15 pong : 0.305 -9.936
# 16 bank_heist : 0.312 245.020
# 17 breakout : 0.317 10.832
# 18 kung_fu_master : 0.369 8557.200
# 19 up_n_down : 0.383 4802.900
# 20 kangaroo : 0.429 1330.800
# 21 assault : 0.504 484.334
# 22 crazy_climber : 0.635 26697.600
# 23 freeway : 0.765 22.640
# 24 jamesbond : 0.932 284.200
# 25 road_runner : 1.128 8847.600
# 26 krull : 1.251 2933.280
#
#
# UAT no-dist pri aug
# 1 private_eye : 0.001 60.000
# 2 chopper_command : 0.004 835.400
# 3 seaquest : 0.006 309.400
# 4 qbert : 0.041 710.450
# 5 amidar : 0.048 88.794
# 6 asterix : 0.063 730.300
# 7 alien : 0.093 869.275
# 8 demon_attack : 0.104 341.200
# 9 gopher : 0.107 487.600
# 10 ms_pacman : 0.115 1073.500
# 11 hero : 0.122 4665.920
# 12 battle_zone : 0.135 7068.000
# 13 pong : 0.189 -14.032 median
# 14 up_n_down : 0.222 3006.620 median
# 15 frostbite : 0.233 1059.640
# 16 kangaroo : 0.330 1035.600
# 17 bank_heist : 0.354 275.940
# 18 crazy_climber : 0.364 19906.600
# 19 breakout : 0.502 16.152
# 20 assault : 0.525 495.150
# 21 kung_fu_master : 0.543 12462.600
# 22 freeway : 0.708 20.958
# 23 jamesbond : 0.846 260.600
# 24 road_runner : 1.426 11185.800
# 25 boxing : 2.177 26.220
# 26 krull : 2.890 4683.526
#
#
# 5k-eps-no-target
# 1 chopper_command : -0.009 752.800
# 2 private_eye : 0.001 100.000
# 3 seaquest : 0.004 254.080
# 4 demon_attack : 0.013 175.430
# 5 qbert : 0.028 534.350
# 6 frostbite : 0.040 235.880
# 7 gopher : 0.040 344.280
# 8 amidar : 0.060 108.524
# 9 asterix : 0.071 795.200
# 10 ms_pacman : 0.087 888.500
# 11 pong : 0.096 -17.328
# 12 alien : 0.098 901.860
# 13 hero : 0.151 5527.960 median
# 14 breakout : 0.188 7.122 median
# 15 battle_zone : 0.214 9798.000
# 16 bank_heist : 0.225 180.180
# 17 kangaroo : 0.280 887.600
# 18 assault : 0.379 419.300
# 19 up_n_down : 0.398 4976.080
# 20 crazy_climber : 0.449 22018.800
# 21 kung_fu_master : 0.558 12810.400
# 22 boxing : 0.637 7.744
# 23 jamesbond : 0.848 261.200
# 24 freeway : 0.933 27.608
# 25 road_runner : 1.020 8002.000
# 26 krull : 1.465 3161.480
#
#
# der
# 1 private_eye : 0.001 97.800
# 2 seaquest : 0.007 354.100
# 3 breakout : 0.007 1.900
# 4 chopper_command : 0.008 861.800
# 5 boxing : 0.008 0.200
# 6 asterix : 0.031 470.800
# 7 pong : 0.040 -19.300
# 8 gopher : 0.043 349.500
# 9 bank_heist : 0.050 51.000
# 10 alien : 0.074 739.900
# 11 qbert : 0.074 1152.900
# 12 amidar : 0.107 188.600
# 13 ms_pacman : 0.135 1204.100 median
# 14 frostbite : 0.188 866.800 median
# 15 hero : 0.196 6857.000
# 16 demon_attack : 0.196 508.000
# 17 up_n_down : 0.210 2877.400
# 18 crazy_climber : 0.216 16185.300
# 19 battle_zone : 0.223 10124.600
# 20 kangaroo : 0.244 779.300
# 21 assault : 0.402 431.200
# 22 kung_fu_master : 0.627 14346.100
# 23 freeway : 0.943 27.900
# 24 jamesbond : 0.996 301.600
# 25 krull : 1.174 2851.500
# 26 road_runner : 1.224 9600.000
#
#
# our_der
# 1 chopper_command : -0.005 778.177
# 2 private_eye : 0.002 166.478
# 3 seaquest : 0.005 258.240
# 4 demon_attack : 0.011 171.350
# 5 qbert : 0.017 387.350
# 6 boxing : 0.034 0.502
# 7 gopher : 0.035 334.000
# 8 asterix : 0.048 605.000
# 9 amidar : 0.050 91.058
# 10 alien : 0.064 668.900
# 11 ms_pacman : 0.085 871.720
# 12 frostbite : 0.117 566.160
# 13 hero : 0.191 6728.410 median
# 14 battle_zone : 0.195 9150.000 median
# 15 up_n_down : 0.243 3248.100
# 16 breakout : 0.244 8.739
# 17 jamesbond : 0.255 98.700
# 18 kung_fu_master : 0.269 6313.000
# 19 assault : 0.291 373.506
# 20 kangaroo : 0.292 924.000
# 21 pong : 0.432 -5.460
# 22 bank_heist : 0.432 333.380
# 23 crazy_climber : 0.483 22881.000
# 24 road_runner : 0.659 5170.200
# 25 krull : 0.682 2325.904
# 26 freeway : 0.830 24.580
#
#
# curl
# 1 private_eye : 0.001 105.200
# 2 seaquest : 0.008 408.000
# 3 asterix : 0.038 524.300
# 4 chopper_command : 0.059 1198.000
# 5 qbert : 0.080 1225.600
# 6 kangaroo : 0.098 345.300
# 7 amidar : 0.132 232.300
# 8 alien : 0.133 1148.200
# 9 hero : 0.175 6235.100
# 10 ms_pacman : 0.178 1492.800
# 11 up_n_down : 0.197 2735.200
# 12 frostbite : 0.201 924.000
# 13 bank_heist : 0.243 193.700 median
# 14 gopher : 0.252 801.400 median
# 15 battle_zone : 0.254 11208.000
# 16 demon_attack : 0.375 834.000
# 17 boxing : 0.392 4.800
# 18 breakout : 0.573 18.200
# 19 assault : 0.618 543.700
# 20 kung_fu_master : 0.624 14280.000
# 21 pong : 0.646 2.100
# 22 crazy_climber : 0.680 27805.600
# 23 road_runner : 0.865 6786.700
# 24 freeway : 0.943 27.900
# 25 jamesbond : 1.355 400.100
# 26 krull : 2.094 3833.600
#
#
# our drq c51 no dueling
# 1 battle_zone : -0.041 938.000
# 2 private_eye : 0.001 100.000
# 3 chopper_command : 0.003 831.500
# 4 qbert : 0.007 252.875
# 5 seaquest : 0.011 519.560
# 6 pong : 0.011 -20.303
# 7 alien : 0.040 501.033
# 8 asterix : 0.054 659.900
# 9 demon_attack : 0.063 266.160
# 10 bank_heist : 0.079 72.280
# 11 amidar : 0.083 148.605
# 12 kung_fu_master : 0.085 2173.800
# 13 frostbite : 0.095 470.860 median
# 14 gopher : 0.097 467.600 median
# 15 ms_pacman : 0.102 982.300
# 16 kangaroo : 0.171 563.200
# 17 hero : 0.182 6444.550
# 18 breakout : 0.269 9.452
# 19 freeway : 0.395 11.690
# 20 assault : 0.585 526.546
# 21 crazy_climber : 0.716 28704.250
# 22 jamesbond : 1.110 332.875
# 23 krull : 1.146 2821.885
# 24 up_n_down : 1.155 13419.725
# 25 road_runner : 1.631 12784.250
# 26 boxing : 2.577 31.022
#
#
# our drq c51 dueling
# 1 private_eye : 0.000 38.600
# 2 seaquest : 0.009 466.200
# 3 bank_heist : 0.023 31.250
# 4 chopper_command : 0.034 1037.200
# 5 qbert : 0.041 703.350
# 6 pong : 0.052 -18.866
# 7 demon_attack : 0.060 261.150
# 8 asterix : 0.061 711.800
# 9 amidar : 0.071 127.264
# 10 alien : 0.073 730.820
# 11 battle_zone : 0.100 5834.000
# 12 frostbite : 0.107 523.300
# 13 hero : 0.108 4247.800 median
# 14 ms_pacman : 0.126 1145.080 median
# 15 gopher : 0.233 759.040
# 16 breakout : 0.254 9.026
# 17 up_n_down : 0.262 3456.840
# 18 kung_fu_master : 0.301 7017.600
# 19 assault : 0.328 392.732
# 20 crazy_climber : 0.568 25012.800
# 21 kangaroo : 0.643 1969.600
# 22 road_runner : 0.644 5052.800
# 23 freeway : 0.876 25.924
# 24 jamesbond : 1.271 377.000
# 25 krull : 1.469 3166.354
# 26 boxing : 2.303 27.738
#
#
# our drq dqn dueling no-dist
# 1 private_eye : 0.000 37.916
# 2 chopper_command : 0.006 853.200
# 3 seaquest : 0.007 361.040
# 4 qbert : 0.041 715.450
# 5 demon_attack : 0.049 241.930
# 6 amidar : 0.071 127.682
# 7 hero : 0.071 3153.920
# 8 alien : 0.084 809.060
# 9 asterix : 0.086 922.700
# 10 frostbite : 0.102 498.740
# 11 ms_pacman : 0.124 1133.220
# 12 battle_zone : 0.151 7622.000
# 13 gopher : 0.161 604.400 median
# 14 pong : 0.161 -15.008 median
# 15 kangaroo : 0.267 848.000
# 16 bank_heist : 0.300 236.000
# 17 up_n_down : 0.356 4505.320
# 18 kung_fu_master : 0.468 10775.600
# 19 freeway : 0.545 16.122
# 20 assault : 0.570 518.656
# 21 crazy_climber : 0.632 26603.400
# 22 breakout : 0.830 25.614
# 23 jamesbond : 0.872 267.800
# 24 boxing : 0.915 11.082
# 25 road_runner : 1.971 15449.200
# 26 krull : 2.195 3940.822
#
#
# our drq 512 no pri
# 1 chopper_command : -0.017 701.600
# 2 private_eye : 0.000 28.506
# 3 seaquest : 0.006 319.000
# 4 qbert : 0.036 647.850
# 5 demon_attack : 0.038 220.510
# 6 pong : 0.045 -19.107
# 7 battle_zone : 0.054 4246.000
# 8 asterix : 0.066 758.300
# 9 alien : 0.072 725.280
# 10 frostbite : 0.077 394.160
# 11 hero : 0.100 3997.730
# 12 amidar : 0.102 181.190
# 13 ms_pacman : 0.144 1262.140 median
# 14 bank_heist : 0.151 125.480 median
# 15 gopher : 0.176 637.440
# 16 kangaroo : 0.229 736.000
# 17 up_n_down : 0.249 3308.840
# 18 kung_fu_master : 0.286 6686.000
# 19 crazy_climber : 0.357 19726.000
# 20 breakout : 0.448 14.592
# 21 freeway : 0.547 16.200
# 22 assault : 0.574 520.422
# 23 boxing : 0.784 9.504
# 24 jamesbond : 0.915 279.500
# 25 road_runner : 1.939 15199.000
# 26 krull : 2.233 3981.984
#
#
# drq
# 1 chopper_command : -0.025 646.595
# 2 private_eye : 0.000 49.179
# 3 seaquest : 0.006 321.823
# 4 asterix : 0.052 637.462
# 5 amidar : 0.053 97.271
# 6 qbert : 0.070 1100.915
# 7 alien : 0.077 761.434
# 8 frostbite : 0.090 449.655
# 9 hero : 0.100 4001.642
# 10 ms_pacman : 0.114 1065.595
# 11 gopher : 0.158 598.388
# 12 bank_heist : 0.247 196.572
# 13 pong : 0.264 -11.374 median
# 14 up_n_down : 0.304 3924.880 median
# 15 kung_fu_master : 0.305 7106.436
# 16 battle_zone : 0.320 13520.619
# 17 kangaroo : 0.335 1052.368
# 18 crazy_climber : 0.356 19694.063
# 19 breakout : 0.445 14.517
# 20 assault : 0.513 489.072
# 21 freeway : 0.520 15.406
# 22 boxing : 0.564 6.866
# 23 demon_attack : 0.588 1222.173
# 24 jamesbond : 0.889 272.336
# 25 road_runner : 1.029 8069.790
# 26 krull : 2.252 4002.307

# %%
corrs = []
import seaborn as sns

from scipy import stats
import matplotlib.pyplot as plt
def r2(x, y):
    return stats.pearsonr(x, y)[0]

for game in games_dfs[0].index:

    game_scores = [df.loc[game]["GameScoreNormalized"] for df in games_dfs]
    hn_medians = [df["GameScoreNormalized"].median() for df in games_dfs]

    corr = r2(game_scores, hn_medians)
    corrs.append(corr)
    
#     sns.jointplot(game_scores, hn_medians, kind="reg", stat_func=r2)
#     plt.xlabel("Human-normalized score on {}".format(game))
#     plt.ylabel("Median human-normalized score on Atari26")
#     plt.show()
corrs = np.array(corrs)
print(np.sum(corrs**2 > 0.1))

indices = np.argsort(-corrs)
for i in indices:
    print(games_dfs[0].index[i], corrs[i])
# Out:
# 10
# pong 0.6725624780420766
# demon_attack 0.578633014542477
# bank_heist 0.5785077724077319
# battle_zone 0.561443683846186
# qbert 0.5550717902598861
# alien 0.45865791343169376
# ms_pacman 0.3200713023934058
# kung_fu_master 0.24579722313517807
# hero 0.20564203311034784
# breakout 0.19196406236985203
# frostbite 0.15356745866571592
# crazy_climber 0.08845723337528857
# gopher 0.014876775313533366
# amidar 0.012361015937032194
# assault 0.0036790138436950176
# kangaroo 8.557964546116892e-05
# chopper_command -0.025169857230015413
# asterix -0.055392656709193015
# krull -0.0645547280502526
# private_eye -0.08590985863498556
# freeway -0.11266679753129734
# road_runner -0.26394167636860033
# jamesbond -0.30557041092446796
# seaquest -0.34050316817721243
# up_n_down -0.428388625902734
# boxing -0.5449034102695254

# %%
sns.jointplot(uat_aug_bn.groupby("game").mean()["ModelNCELoss"],
              uat_aug_bn.groupby("game").mean()["GameScoreNormalized"],
              kind="reg", stat_func=r2)
# Out:
# C:\Users\user1\AppData\Local\conda\conda\envs\pytorch\lib\site-packages\seaborn\axisgrid.py:1847: UserWarning: JointGrid annotation is deprecated and will be removed in a future release.
#   warnings.warn(UserWarning(msg))

# %%
indices = np.argsort(games_dfs[-2]["GameScoreNormalized"])
games_dfs[-2]["GameScoreNormalized"][indices]
# Out:
# game
# chopper_command   -0.016634
# private_eye        0.000052
# seaquest           0.005969
# qbert              0.036412
# demon_attack       0.037611
# pong               0.045113
# battle_zone        0.054153
# asterix            0.066114
# alien              0.072100
# frostbite          0.077049
# hero               0.099691
# amidar             0.102346
# ms_pacman          0.143708
# bank_heist         0.150602
# gopher             0.176268
# kangaroo           0.229299
# up_n_down          0.248700
# kung_fu_master     0.285949
# crazy_climber      0.357121
# breakout           0.447639
# freeway            0.547297
# assault            0.573560
# boxing             0.783667
# jamesbond          0.914901
# road_runner        1.938789
# krull              2.233240
# Name: GameScoreNormalized, dtype: float64

# %%
for i in [8, 9, -4]:
    print(names[i])
    indices = np.array(list(np.argsort(-games_dfs[i]["GameScoreNormalized"])))
    print(games_dfs[i].iloc[indices][["GameScoreAverage", "GameScoreNormalized"]])
    print()
# Out:
# -tag: gl_uat_hn1_no_dist-
#                  GameScoreAverage  GameScoreNormalized
# game
# krull                    2933.280             1.250848
# road_runner              8847.600             1.127989
# jamesbond                 284.200             0.932067
# freeway                    22.640             0.764865
# crazy_climber           26697.600             0.635441
# assault                   484.334             0.504107
# kangaroo                 1330.800             0.428696
# up_n_down                4802.900             0.382579
# kung_fu_master           8557.200             0.369195
# breakout                   10.832             0.317083
# bank_heist                245.020             0.312383
# pong                       -9.936             0.304929
# boxing                      3.158             0.254833
# hero                     7533.270             0.218336
# battle_zone              8708.000             0.182270
# ms_pacman                1016.460             0.106732
# frostbite                 479.580             0.097056
# amidar                    145.760             0.081671
# alien                     758.480             0.076911
# asterix                   729.900             0.062689
# demon_attack              252.990             0.055468
# qbert                     802.750             0.048066
# gopher                    311.520             0.025022
# seaquest                  258.640             0.004531
# chopper_command           822.750             0.001787
# private_eye               100.000             0.001080
#
# -tag: gl_aug_uat_hn1_no_dist-
#                  GameScoreAverage  GameScoreNormalized
# game
# krull                    3048.738             1.359005
# road_runner              8636.000             1.100977
# jamesbond                 273.200             0.891892
# freeway                    25.986             0.877905
# kangaroo                 1512.600             0.489641
# assault                   424.110             0.388202
# kung_fu_master           7135.200             0.305933
# up_n_down                3942.260             0.305459
# bank_heist                234.960             0.298768
# boxing                      3.656             0.296333
# pong                      -10.386             0.292181
# breakout                    7.746             0.209931
# crazy_climber           15058.200             0.170774
# battle_zone              8138.000             0.165903
# hero                     5705.540             0.157001
# ms_pacman                 848.800             0.081498
# alien                     725.040             0.072065
# asterix                   710.600             0.060362
# amidar                    100.460             0.055237
# qbert                     855.150             0.052008
# frostbite                 248.920             0.043031
# gopher                    344.720             0.040429
# demon_attack              172.890             0.011430
# seaquest                  301.880             0.005561
# private_eye               113.700             0.001277
# chopper_command           672.000            -0.021135
#
# UAT
#                  GameScoreAverage  GameScoreNormalized
# game
# krull                    3940.822             2.194681
# road_runner             15449.200             1.970728
# boxing                     11.082             0.915167
# jamesbond                 267.800             0.872169
# breakout                   25.614             0.830347
# crazy_climber           26603.400             0.631680
# assault                   518.656             0.570162
# freeway                    16.122             0.544662
# kung_fu_master          10775.600             0.467888
# up_n_down                4505.320             0.355913
# bank_heist                236.000             0.300176
# kangaroo                  848.000             0.266845
# pong                      -15.008             0.161246
# gopher                    604.400             0.160936
# battle_zone              7622.000             0.151088
# ms_pacman                1133.220             0.124305
# frostbite                 498.740             0.101544
# asterix                   922.700             0.085937
# alien                     809.060             0.084242
# hero                     3153.920             0.071375
# amidar                    127.682             0.071122
# demon_attack              241.930             0.049387
# qbert                     715.450             0.041498
# seaquest                  361.040             0.006970
# chopper_command           853.200             0.006416
# private_eye                37.916             0.000187

# %%
uat_data = pandas.read_csv("uat_sweep.csv")
byol_data = pandas.read_csv("byol_prototypes.csv")

byol_sweeps, byol_names = split_on_fields(byol_data, ["tag"], 30)

hnf_1 = pandas.read_csv("uat_hnf_1.csv")
hnf_1_sweeps, hnf_1_names = split_on_fields(hnf_1, ["tag"], 30)

sweeps, names = split_on_fields(uat_data, ["tag"], 30)
sweeps = sweeps + hnf_1_sweeps + byol_sweeps + \
        [
       fixed_jat_gl,
       uat_aug_bn,
       our_drq_dqn,
       atari_ilya_scores]
names = names + hnf_1_names + byol_names + [
          "UAT", 
          "UAT no-dist pri aug",
          "Our DRQ",
          "drq"]

# %%
games_dfs = compare_dfs(sweeps, names)
# Out:
# Human Scores:
# -tag: g_uat_both_aug_no_dist-: Median: 0.138, Mean: 0.207
# -tag: eps10k_g_uat_aug_no_dist-: Median: 0.125, Mean: 0.192
# -tag: g_uat_3232_aug_no_dist-: Median: 0.134, Mean: 0.186
# -tag: gl_uat_aug_no_dist-: Median: 0.098, Mean: 0.132
# -tag: g_uat_int_aug_no_dist-: Median: 0.171, Mean: 0.160
# -tag: g_uat_momentum_aug_no_dist-: Median: 0.143, Mean: 0.183
# -tag: g_uat_aug_no_dist-: Median: 0.127, Mean: 0.192
# -tag: g_uat_int_32_no_dist-: Median: 0.132, Mean: 0.189
# -tag: gl_uat_hn1_no_dist-: Median: 0.132, Mean: 0.158
# -tag: gl_aug_uat_hn1_no_dist-: Median: 0.120, Mean: 0.184
# -tag: byol_aug_l-: Median: 0.182, Mean: 0.278
# -tag: byol_aug_g-: Median: 0.151, Mean: 0.196
# UAT: Median: 0.145, Mean: 0.182
# UAT no-dist pri aug: Median: 0.125, Mean: 0.197
# Our DRQ: Median: 0.138, Mean: 0.172
# drq: Median: 0.255, Mean: 0.248
#
# Comparison over 8 games:
#
# -tag: g_uat_both_aug_no_dist- above -tag: eps10k_g_uat_aug_no_dist-: 3, -0.125, 0.415
# -tag: g_uat_both_aug_no_dist- above -tag: g_uat_3232_aug_no_dist-: 4, 0.031, 0.151
# -tag: g_uat_both_aug_no_dist- above -tag: gl_uat_aug_no_dist-: 7, 0.752, 0.887
# -tag: g_uat_both_aug_no_dist- above -tag: g_uat_int_aug_no_dist-: 5, 0.458, 0.453
# -tag: g_uat_both_aug_no_dist- above -tag: g_uat_momentum_aug_no_dist-: 6, 0.230, 0.256
# -tag: g_uat_both_aug_no_dist- above -tag: g_uat_aug_no_dist-: 5, 0.119, 0.107
# -tag: g_uat_both_aug_no_dist- above -tag: g_uat_int_32_no_dist-: 5, 0.227, 0.106
# -tag: g_uat_both_aug_no_dist- above -tag: gl_uat_hn1_no_dist-: 6, 0.238, 0.580
# -tag: g_uat_both_aug_no_dist- above -tag: gl_aug_uat_hn1_no_dist-: 3, -0.042, 0.235
# -tag: g_uat_both_aug_no_dist- above -tag: byol_aug_l-: 3, -0.628, -0.449
# -tag: g_uat_both_aug_no_dist- above -tag: byol_aug_g-: 5, 0.196, 0.111
# -tag: g_uat_both_aug_no_dist- above UAT: 4, 0.091, 0.210
# -tag: g_uat_both_aug_no_dist- above UAT no-dist pri aug: 5, 0.041, 0.078
# -tag: g_uat_both_aug_no_dist- above Our DRQ: 5, 0.403, 0.379
# -tag: g_uat_both_aug_no_dist- above drq: 4, 0.053, -0.796
#
# -tag: eps10k_g_uat_aug_no_dist- above -tag: g_uat_both_aug_no_dist-: 5, 0.125, -0.415
# -tag: eps10k_g_uat_aug_no_dist- above -tag: g_uat_3232_aug_no_dist-: 3, -0.059, -0.145
# -tag: eps10k_g_uat_aug_no_dist- above -tag: gl_uat_aug_no_dist-: 7, 0.699, 0.592
# -tag: eps10k_g_uat_aug_no_dist- above -tag: g_uat_int_aug_no_dist-: 6, 0.302, 0.029
# -tag: eps10k_g_uat_aug_no_dist- above -tag: g_uat_momentum_aug_no_dist-: 4, 0.086, -0.066
# -tag: eps10k_g_uat_aug_no_dist- above -tag: g_uat_aug_no_dist-: 5, 0.103, -0.201
# -tag: eps10k_g_uat_aug_no_dist- above -tag: g_uat_int_32_no_dist-: 6, 0.256, -0.243
# -tag: eps10k_g_uat_aug_no_dist- above -tag: gl_uat_hn1_no_dist-: 6, 0.465, -0.086
# -tag: eps10k_g_uat_aug_no_dist- above -tag: gl_aug_uat_hn1_no_dist-: 6, 0.200, -0.328
# -tag: eps10k_g_uat_aug_no_dist- above -tag: byol_aug_l-: 3, -0.318, -1.087
# -tag: eps10k_g_uat_aug_no_dist- above -tag: byol_aug_g-: 6, 0.241, -0.531
# -tag: eps10k_g_uat_aug_no_dist- above UAT: 4, 0.230, -0.270
# -tag: eps10k_g_uat_aug_no_dist- above UAT no-dist pri aug: 6, 0.167, -0.265
# -tag: eps10k_g_uat_aug_no_dist- above Our DRQ: 5, 0.284, 0.071
# -tag: eps10k_g_uat_aug_no_dist- above drq: 3, -0.477, -1.158
#
# -tag: g_uat_3232_aug_no_dist- above -tag: g_uat_both_aug_no_dist-: 4, -0.031, -0.151
# -tag: g_uat_3232_aug_no_dist- above -tag: eps10k_g_uat_aug_no_dist-: 5, 0.059, 0.145
# -tag: g_uat_3232_aug_no_dist- above -tag: gl_uat_aug_no_dist-: 7, 0.452, 0.764
# -tag: g_uat_3232_aug_no_dist- above -tag: g_uat_int_aug_no_dist-: 5, 0.216, 0.350
# -tag: g_uat_3232_aug_no_dist- above -tag: g_uat_momentum_aug_no_dist-: 3, -0.043, 0.144
# -tag: g_uat_3232_aug_no_dist- above -tag: g_uat_aug_no_dist-: 2, -0.153, -0.034
# -tag: g_uat_3232_aug_no_dist- above -tag: g_uat_int_32_no_dist-: 4, -0.072, -0.030
# -tag: g_uat_3232_aug_no_dist- above -tag: gl_uat_hn1_no_dist-: 4, 0.211, 0.401
# -tag: g_uat_3232_aug_no_dist- above -tag: gl_aug_uat_hn1_no_dist-: 4, -0.027, 0.104
# -tag: g_uat_3232_aug_no_dist- above -tag: byol_aug_l-: 2, -0.527, -0.643
# -tag: g_uat_3232_aug_no_dist- above -tag: byol_aug_g-: 4, 0.012, -0.075
# -tag: g_uat_3232_aug_no_dist- above UAT: 5, 0.052, 0.067
# -tag: g_uat_3232_aug_no_dist- above UAT no-dist pri aug: 3, -0.076, -0.061
# -tag: g_uat_3232_aug_no_dist- above Our DRQ: 4, 0.035, 0.276
# -tag: g_uat_3232_aug_no_dist- above drq: 4, -0.428, -0.805
#
# -tag: gl_uat_aug_no_dist- above -tag: g_uat_both_aug_no_dist-: 1, -0.752, -0.887
# -tag: gl_uat_aug_no_dist- above -tag: eps10k_g_uat_aug_no_dist-: 1, -0.699, -0.592
# -tag: gl_uat_aug_no_dist- above -tag: g_uat_3232_aug_no_dist-: 1, -0.452, -0.764
# -tag: gl_uat_aug_no_dist- above -tag: g_uat_int_aug_no_dist-: 3, -0.115, -0.489
# -tag: gl_uat_aug_no_dist- above -tag: g_uat_momentum_aug_no_dist-: 2, -0.510, -0.704
# -tag: gl_uat_aug_no_dist- above -tag: g_uat_aug_no_dist-: 1, -0.648, -0.764
# -tag: gl_uat_aug_no_dist- above -tag: g_uat_int_32_no_dist-: 0, -0.437, -0.764
# -tag: gl_uat_aug_no_dist- above -tag: gl_uat_hn1_no_dist-: 3, -0.369, -0.477
# -tag: gl_uat_aug_no_dist- above -tag: gl_aug_uat_hn1_no_dist-: 2, -0.445, -0.769
# -tag: gl_uat_aug_no_dist- above -tag: byol_aug_l-: 2, -1.265, -1.563
# -tag: gl_uat_aug_no_dist- above -tag: byol_aug_g-: 1, -0.307, -0.919
# -tag: gl_uat_aug_no_dist- above UAT: 2, -0.317, -0.708
# -tag: gl_uat_aug_no_dist- above UAT no-dist pri aug: 2, -0.648, -0.797
# -tag: gl_uat_aug_no_dist- above Our DRQ: 1, -0.331, -0.480
# -tag: gl_uat_aug_no_dist- above drq: 2, -0.952, -2.375
#
# -tag: g_uat_int_aug_no_dist- above -tag: g_uat_both_aug_no_dist-: 3, -0.458, -0.453
# -tag: g_uat_int_aug_no_dist- above -tag: eps10k_g_uat_aug_no_dist-: 2, -0.302, -0.029
# -tag: g_uat_int_aug_no_dist- above -tag: g_uat_3232_aug_no_dist-: 3, -0.216, -0.350
# -tag: g_uat_int_aug_no_dist- above -tag: gl_uat_aug_no_dist-: 5, 0.115, 0.489
# -tag: g_uat_int_aug_no_dist- above -tag: g_uat_momentum_aug_no_dist-: 3, -0.387, -0.183
# -tag: g_uat_int_aug_no_dist- above -tag: g_uat_aug_no_dist-: 3, -0.403, -0.346
# -tag: g_uat_int_aug_no_dist- above -tag: g_uat_int_32_no_dist-: 3, -0.289, -0.326
# -tag: g_uat_int_aug_no_dist- above -tag: gl_uat_hn1_no_dist-: 4, 0.104, 0.085
# -tag: g_uat_int_aug_no_dist- above -tag: gl_aug_uat_hn1_no_dist-: 4, -0.171, -0.254
# -tag: g_uat_int_aug_no_dist- above -tag: byol_aug_l-: 3, -0.393, -1.080
# -tag: g_uat_int_aug_no_dist- above -tag: byol_aug_g-: 2, -0.267, -0.307
# -tag: g_uat_int_aug_no_dist- above UAT: 2, -0.244, -0.217
# -tag: g_uat_int_aug_no_dist- above UAT no-dist pri aug: 4, -0.281, -0.379
# -tag: g_uat_int_aug_no_dist- above Our DRQ: 4, -0.176, -0.050
# -tag: g_uat_int_aug_no_dist- above drq: 2, -0.342, -2.035
#
# -tag: g_uat_momentum_aug_no_dist- above -tag: g_uat_both_aug_no_dist-: 2, -0.230, -0.256
# -tag: g_uat_momentum_aug_no_dist- above -tag: eps10k_g_uat_aug_no_dist-: 4, -0.086, 0.066
# -tag: g_uat_momentum_aug_no_dist- above -tag: g_uat_3232_aug_no_dist-: 5, 0.043, -0.144
# -tag: g_uat_momentum_aug_no_dist- above -tag: gl_uat_aug_no_dist-: 6, 0.510, 0.704
# -tag: g_uat_momentum_aug_no_dist- above -tag: g_uat_int_aug_no_dist-: 5, 0.387, 0.183
# -tag: g_uat_momentum_aug_no_dist- above -tag: g_uat_aug_no_dist-: 3, -0.109, -0.167
# -tag: g_uat_momentum_aug_no_dist- above -tag: g_uat_int_32_no_dist-: 4, 0.014, -0.146
# -tag: g_uat_momentum_aug_no_dist- above -tag: gl_uat_hn1_no_dist-: 4, 0.381, 0.286
# -tag: g_uat_momentum_aug_no_dist- above -tag: gl_aug_uat_hn1_no_dist-: 4, 0.066, -0.125
# -tag: g_uat_momentum_aug_no_dist- above -tag: byol_aug_l-: 2, -0.743, -0.764
# -tag: g_uat_momentum_aug_no_dist- above -tag: byol_aug_g-: 5, 0.120, -0.154
# -tag: g_uat_momentum_aug_no_dist- above UAT: 3, -0.070, -0.054
# -tag: g_uat_momentum_aug_no_dist- above UAT no-dist pri aug: 3, -0.072, -0.192
# -tag: g_uat_momentum_aug_no_dist- above Our DRQ: 5, 0.175, 0.170
# -tag: g_uat_momentum_aug_no_dist- above drq: 3, -0.447, -1.095
#
# -tag: g_uat_aug_no_dist- above -tag: g_uat_both_aug_no_dist-: 3, -0.119, -0.107
# -tag: g_uat_aug_no_dist- above -tag: eps10k_g_uat_aug_no_dist-: 3, -0.103, 0.201
# -tag: g_uat_aug_no_dist- above -tag: g_uat_3232_aug_no_dist-: 6, 0.153, 0.034
# -tag: g_uat_aug_no_dist- above -tag: gl_uat_aug_no_dist-: 7, 0.648, 0.764
# -tag: g_uat_aug_no_dist- above -tag: g_uat_int_aug_no_dist-: 5, 0.403, 0.346
# -tag: g_uat_aug_no_dist- above -tag: g_uat_momentum_aug_no_dist-: 5, 0.109, 0.167
# -tag: g_uat_aug_no_dist- above -tag: g_uat_int_32_no_dist-: 4, 0.097, 0.004
# -tag: g_uat_aug_no_dist- above -tag: gl_uat_hn1_no_dist-: 4, 0.403, 0.465
# -tag: g_uat_aug_no_dist- above -tag: gl_aug_uat_hn1_no_dist-: 3, -0.149, 0.183
# -tag: g_uat_aug_no_dist- above -tag: byol_aug_l-: 2, -0.489, -0.584
# -tag: g_uat_aug_no_dist- above -tag: byol_aug_g-: 4, 0.128, -0.014
# -tag: g_uat_aug_no_dist- above UAT: 6, 0.213, 0.089
# -tag: g_uat_aug_no_dist- above UAT no-dist pri aug: 2, 0.000, -0.025
# -tag: g_uat_aug_no_dist- above Our DRQ: 5, 0.170, 0.274
# -tag: g_uat_aug_no_dist- above drq: 4, -0.311, -0.888
#
# -tag: g_uat_int_32_no_dist- above -tag: g_uat_both_aug_no_dist-: 3, -0.227, -0.106
# -tag: g_uat_int_32_no_dist- above -tag: eps10k_g_uat_aug_no_dist-: 2, -0.256, 0.243
# -tag: g_uat_int_32_no_dist- above -tag: g_uat_3232_aug_no_dist-: 4, 0.072, 0.030
# -tag: g_uat_int_32_no_dist- above -tag: gl_uat_aug_no_dist-: 8, 0.437, 0.764
# -tag: g_uat_int_32_no_dist- above -tag: g_uat_int_aug_no_dist-: 5, 0.289, 0.326
# -tag: g_uat_int_32_no_dist- above -tag: g_uat_momentum_aug_no_dist-: 4, -0.014, 0.146
# -tag: g_uat_int_32_no_dist- above -tag: g_uat_aug_no_dist-: 4, -0.097, -0.004
# -tag: g_uat_int_32_no_dist- above -tag: gl_uat_hn1_no_dist-: 4, 0.280, 0.484
# -tag: g_uat_int_32_no_dist- above -tag: gl_aug_uat_hn1_no_dist-: 3, -0.122, 0.220
# -tag: g_uat_int_32_no_dist- above -tag: byol_aug_l-: 2, -0.517, -0.576
# -tag: g_uat_int_32_no_dist- above -tag: byol_aug_g-: 3, -0.031, 0.003
# -tag: g_uat_int_32_no_dist- above UAT: 5, 0.317, 0.089
# -tag: g_uat_int_32_no_dist- above UAT no-dist pri aug: 4, -0.032, -0.029
# -tag: g_uat_int_32_no_dist- above Our DRQ: 6, 0.202, 0.261
# -tag: g_uat_int_32_no_dist- above drq: 4, -0.187, -0.984
#
# -tag: gl_uat_hn1_no_dist- above -tag: g_uat_both_aug_no_dist-: 2, -0.238, -0.580
# -tag: gl_uat_hn1_no_dist- above -tag: eps10k_g_uat_aug_no_dist-: 2, -0.465, 0.086
# -tag: gl_uat_hn1_no_dist- above -tag: g_uat_3232_aug_no_dist-: 4, -0.211, -0.401
# -tag: gl_uat_hn1_no_dist- above -tag: gl_uat_aug_no_dist-: 5, 0.369, 0.477
# -tag: gl_uat_hn1_no_dist- above -tag: g_uat_int_aug_no_dist-: 4, -0.104, -0.085
# -tag: gl_uat_hn1_no_dist- above -tag: g_uat_momentum_aug_no_dist-: 4, -0.381, -0.286
# -tag: gl_uat_hn1_no_dist- above -tag: g_uat_aug_no_dist-: 4, -0.403, -0.465
# -tag: gl_uat_hn1_no_dist- above -tag: g_uat_int_32_no_dist-: 4, -0.280, -0.484
# -tag: gl_uat_hn1_no_dist- above -tag: gl_aug_uat_hn1_no_dist-: 3, -0.230, -0.345
# -tag: gl_uat_hn1_no_dist- above -tag: byol_aug_l-: 4, -0.102, -1.248
# -tag: gl_uat_hn1_no_dist- above -tag: byol_aug_g-: 4, -0.267, -0.400
# -tag: gl_uat_hn1_no_dist- above UAT: 4, -0.002, -0.354
# -tag: gl_uat_hn1_no_dist- above UAT no-dist pri aug: 3, -0.266, -0.515
# -tag: gl_uat_hn1_no_dist- above Our DRQ: 5, 0.171, -0.161
# -tag: gl_uat_hn1_no_dist- above drq: 3, -0.934, -1.799
# -tag: gl_aug_uat_hn1_no_dist- above -tag: g_uat_both_aug_no_dist-: 5, 0.042, -0.235
# -tag: gl_aug_uat_hn1_no_dist- above -tag: eps10k_g_uat_aug_no_dist-: 2, -0.200, 0.328
# -tag: gl_aug_uat_hn1_no_dist- above -tag: g_uat_3232_aug_no_dist-: 4, 0.027, -0.104
# -tag: gl_aug_uat_hn1_no_dist- above -tag: gl_uat_aug_no_dist-: 6, 0.445, 0.769
# -tag: gl_aug_uat_hn1_no_dist- above -tag: g_uat_int_aug_no_dist-: 4, 0.171, 0.254
# -tag: gl_aug_uat_hn1_no_dist- above -tag: g_uat_momentum_aug_no_dist-: 4, -0.066, 0.125
# -tag: gl_aug_uat_hn1_no_dist- above -tag: g_uat_aug_no_dist-: 5, 0.149, -0.183
# -tag: gl_aug_uat_hn1_no_dist- above -tag: g_uat_int_32_no_dist-: 5, 0.122, -0.220
# -tag: gl_aug_uat_hn1_no_dist- above -tag: gl_uat_hn1_no_dist-: 5, 0.230, 0.345
# -tag: gl_aug_uat_hn1_no_dist- above -tag: byol_aug_l-: 3, -0.254, -0.850
# -tag: gl_aug_uat_hn1_no_dist- above -tag: byol_aug_g-: 2, -0.156, 0.002
# -tag: gl_aug_uat_hn1_no_dist- above UAT: 6, 0.381, -0.069
# -tag: gl_aug_uat_hn1_no_dist- above UAT no-dist pri aug: 5, 0.084, -0.223
# -tag: gl_aug_uat_hn1_no_dist- above Our DRQ: 5, 0.225, 0.130
# -tag: gl_aug_uat_hn1_no_dist- above drq: 4, -0.230, -0.980
#
# -tag: byol_aug_l- above -tag: g_uat_both_aug_no_dist-: 5, 0.628, 0.449
# -tag: byol_aug_l- above -tag: eps10k_g_uat_aug_no_dist-: 5, 0.318, 1.087
# -tag: byol_aug_l- above -tag: g_uat_3232_aug_no_dist-: 6, 0.527, 0.643
# -tag: byol_aug_l- above -tag: gl_uat_aug_no_dist-: 6, 1.265, 1.563
# -tag: byol_aug_l- above -tag: g_uat_int_aug_no_dist-: 5, 0.393, 1.080
# -tag: byol_aug_l- above -tag: g_uat_momentum_aug_no_dist-: 6, 0.743, 0.764
# -tag: byol_aug_l- above -tag: g_uat_aug_no_dist-: 6, 0.489, 0.584
# -tag: byol_aug_l- above -tag: g_uat_int_32_no_dist-: 6, 0.517, 0.576
# -tag: byol_aug_l- above -tag: gl_uat_hn1_no_dist-: 4, 0.102, 1.248
# -tag: byol_aug_l- above -tag: gl_aug_uat_hn1_no_dist-: 5, 0.254, 0.850
# -tag: byol_aug_l- above -tag: byol_aug_g-: 4, 0.216, 0.612
# -tag: byol_aug_l- above UAT: 5, 0.598, 0.729
# -tag: byol_aug_l- above UAT no-dist pri aug: 6, 0.490, 0.535
# -tag: byol_aug_l- above Our DRQ: 6, 0.589, 0.940
# -tag: byol_aug_l- above drq: 4, 0.127, -0.118
#
# -tag: byol_aug_g- above -tag: g_uat_both_aug_no_dist-: 3, -0.196, -0.111
# -tag: byol_aug_g- above -tag: eps10k_g_uat_aug_no_dist-: 2, -0.241, 0.531
# -tag: byol_aug_g- above -tag: g_uat_3232_aug_no_dist-: 4, -0.012, 0.075
# -tag: byol_aug_g- above -tag: gl_uat_aug_no_dist-: 7, 0.307, 0.919
# -tag: byol_aug_g- above -tag: g_uat_int_aug_no_dist-: 6, 0.267, 0.307
# -tag: byol_aug_g- above -tag: g_uat_momentum_aug_no_dist-: 3, -0.120, 0.154
# -tag: byol_aug_g- above -tag: g_uat_aug_no_dist-: 4, -0.128, 0.014
# -tag: byol_aug_g- above -tag: g_uat_int_32_no_dist-: 5, 0.031, -0.003
# -tag: byol_aug_g- above -tag: gl_uat_hn1_no_dist-: 4, 0.267, 0.400
# -tag: byol_aug_g- above -tag: gl_aug_uat_hn1_no_dist-: 6, 0.156, -0.002
# -tag: byol_aug_g- above -tag: byol_aug_l-: 4, -0.216, -0.612
# -tag: byol_aug_g- above UAT: 5, 0.373, 0.078
# -tag: byol_aug_g- above UAT no-dist pri aug: 4, -0.012, -0.037
# -tag: byol_aug_g- above Our DRQ: 6, 0.077, 0.318
# -tag: byol_aug_g- above drq: 4, -0.108, -0.935
#
# UAT above -tag: g_uat_both_aug_no_dist-: 4, -0.091, -0.210
# UAT above -tag: eps10k_g_uat_aug_no_dist-: 4, -0.230, 0.270
# UAT above -tag: g_uat_3232_aug_no_dist-: 3, -0.052, -0.067
# UAT above -tag: gl_uat_aug_no_dist-: 6, 0.317, 0.708
# UAT above -tag: g_uat_int_aug_no_dist-: 6, 0.244, 0.217
# UAT above -tag: g_uat_momentum_aug_no_dist-: 5, 0.070, 0.054
# UAT above -tag: g_uat_aug_no_dist-: 2, -0.213, -0.089
# UAT above -tag: g_uat_int_32_no_dist-: 3, -0.317, -0.089
# UAT above -tag: gl_uat_hn1_no_dist-: 4, 0.002, 0.354
# UAT above -tag: gl_aug_uat_hn1_no_dist-: 2, -0.381, 0.069
# UAT above -tag: byol_aug_l-: 3, -0.598, -0.729
# UAT above -tag: byol_aug_g-: 3, -0.373, -0.078
# UAT above UAT no-dist pri aug: 3, -0.203, -0.126
# UAT above Our DRQ: 5, 0.156, 0.173
# UAT above drq: 3, -0.073, -1.435
#
# UAT no-dist pri aug above -tag: g_uat_both_aug_no_dist-: 3, -0.041, -0.078
# UAT no-dist pri aug above -tag: eps10k_g_uat_aug_no_dist-: 2, -0.167, 0.265
# UAT no-dist pri aug above -tag: g_uat_3232_aug_no_dist-: 5, 0.076, 0.061
# UAT no-dist pri aug above -tag: gl_uat_aug_no_dist-: 6, 0.648, 0.797
# UAT no-dist pri aug above -tag: g_uat_int_aug_no_dist-: 4, 0.281, 0.379
# UAT no-dist pri aug above -tag: g_uat_momentum_aug_no_dist-: 5, 0.072, 0.192
# UAT no-dist pri aug above -tag: g_uat_aug_no_dist-: 2, 0.000, 0.025
# UAT no-dist pri aug above -tag: g_uat_int_32_no_dist-: 4, 0.032, 0.029
# UAT no-dist pri aug above -tag: gl_uat_hn1_no_dist-: 5, 0.266, 0.515
# UAT no-dist pri aug above -tag: gl_aug_uat_hn1_no_dist-: 3, -0.084, 0.223
# UAT no-dist pri aug above -tag: byol_aug_l-: 2, -0.490, -0.535
# UAT no-dist pri aug above -tag: byol_aug_g-: 4, 0.012, 0.037
# UAT no-dist pri aug above UAT: 5, 0.203, 0.126
# UAT no-dist pri aug above Our DRQ: 5, 0.248, 0.298
# UAT no-dist pri aug above drq: 4, -0.331, -0.862
#
# Our DRQ above -tag: g_uat_both_aug_no_dist-: 3, -0.403, -0.379
# Our DRQ above -tag: eps10k_g_uat_aug_no_dist-: 3, -0.284, -0.071
# Our DRQ above -tag: g_uat_3232_aug_no_dist-: 4, -0.035, -0.276
# Our DRQ above -tag: gl_uat_aug_no_dist-: 7, 0.331, 0.480
# Our DRQ above -tag: g_uat_int_aug_no_dist-: 4, 0.176, 0.050
# Our DRQ above -tag: g_uat_momentum_aug_no_dist-: 3, -0.175, -0.170
# Our DRQ above -tag: g_uat_aug_no_dist-: 3, -0.170, -0.274
# Our DRQ above -tag: g_uat_int_32_no_dist-: 2, -0.202, -0.261
# Our DRQ above -tag: gl_uat_hn1_no_dist-: 3, -0.171, 0.161
# Our DRQ above -tag: gl_aug_uat_hn1_no_dist-: 3, -0.225, -0.130
# Our DRQ above -tag: byol_aug_l-: 2, -0.589, -0.940
# Our DRQ above -tag: byol_aug_g-: 2, -0.077, -0.318
# Our DRQ above UAT: 3, -0.156, -0.173
# Our DRQ above UAT no-dist pri aug: 3, -0.248, -0.298
# Our DRQ above drq: 4, -0.428, -1.749
#
# drq above -tag: g_uat_both_aug_no_dist-: 4, -0.053, 0.796
# drq above -tag: eps10k_g_uat_aug_no_dist-: 5, 0.477, 1.158
# drq above -tag: g_uat_3232_aug_no_dist-: 4, 0.428, 0.805
# drq above -tag: gl_uat_aug_no_dist-: 6, 0.952, 2.375
# drq above -tag: g_uat_int_aug_no_dist-: 6, 0.342, 2.035
# drq above -tag: g_uat_momentum_aug_no_dist-: 5, 0.447, 1.095
# drq above -tag: g_uat_aug_no_dist-: 4, 0.311, 0.888
# drq above -tag: g_uat_int_32_no_dist-: 4, 0.187, 0.984
# drq above -tag: gl_uat_hn1_no_dist-: 5, 0.934, 1.799
# drq above -tag: gl_aug_uat_hn1_no_dist-: 4, 0.230, 0.980
# drq above -tag: byol_aug_l-: 4, -0.127, 0.118
# drq above -tag: byol_aug_g-: 4, 0.108, 0.935
# drq above UAT: 5, 0.073, 1.435
# drq above UAT no-dist pri aug: 4, 0.331, 0.862
# drq above Our DRQ: 4, 0.428, 1.749

# %%
sweeps[-4][sweeps[-4].game == "pong"]["GameScoreAverage"]
# Out:
# 39    -7.14
# 40    -7.22
# 53   -11.04
# 59   -12.11
# 60   -12.17
# Name: GameScoreAverage, dtype: float64

# %%
for i in range(len(names)):
    print(names[i])
    indices = np.array(list(np.argsort(-games_dfs[i]["GameScoreNormalized"])))
    print(games_dfs[i].iloc[indices][["GameScoreAverage", "GameScoreNormalized"]])
    print()
# Out:
# -tag: g_uat_both_aug_no_dist-
#                 GameScoreAverage  GameScoreNormalized
# game
# kung_fu_master         14149.800             0.618001
# ms_pacman               1393.480             0.163475
# battle_zone             6262.000             0.112038
# alien                    886.780             0.095506
# qbert                    681.875             0.038972
#
# -tag: eps10k_g_uat_aug_no_dist-
#                 GameScoreAverage  GameScoreNormalized
# game
# kung_fu_master          15592.00             0.682162
# ms_pacman                1389.56             0.162885
# battle_zone              7122.00             0.136731
# alien                     919.34             0.100225
# qbert                     778.80             0.046264
#
# -tag: g_uat_3232_aug_no_dist-
#                 GameScoreAverage  GameScoreNormalized
# game
# kung_fu_master         11626.750             0.505755
# battle_zone             7400.000             0.144713
# ms_pacman               1069.325             0.114689
# alien                    763.120             0.077584
# qbert                    780.125             0.046364
#
# -tag: gl_uat_aug_no_dist-
#                 GameScoreAverage  GameScoreNormalized
# game
# kung_fu_master           9269.20             0.400871
# ms_pacman                1163.62             0.128880
# battle_zone              5732.00             0.096820
# alien                     715.66             0.070705
# qbert                     713.45             0.041347
#
# -tag: g_uat_int_aug_no_dist-
#                 GameScoreAverage  GameScoreNormalized
# game
# kung_fu_master       6305.400000             0.269017
# battle_zone         10556.666667             0.235350
# ms_pacman            1258.425000             0.143149
# alien                 706.633333             0.069397
# qbert                 719.100000             0.041772
#
# -tag: g_uat_momentum_aug_no_dist-
#                 GameScoreAverage  GameScoreNormalized
# game
# kung_fu_master         11942.000             0.519780
# ms_pacman                982.080             0.101558
# alien                    851.125             0.090338
# battle_zone             4230.000             0.053693
# qbert                    790.000             0.047107
#
# -tag: g_uat_aug_no_dist-
#                 GameScoreAverage  GameScoreNormalized
# game
# kung_fu_master       12462.60000             0.542940
# battle_zone           7068.00000             0.135181
# ms_pacman             1091.25000             0.117988
# alien                  821.34375             0.086022
# qbert                  832.47500             0.050302
#
# -tag: g_uat_int_32_no_dist-
#                 GameScoreAverage  GameScoreNormalized
# game
# kung_fu_master          10286.40             0.446125
# ms_pacman                1254.96             0.142628
# battle_zone              6572.50             0.120953
# alien                     830.00             0.087277
# qbert                     752.15             0.044259
#
# -tag: gl_uat_hn1_no_dist-
#                 GameScoreAverage  GameScoreNormalized
# game
# kung_fu_master           5020.75             0.211865
# battle_zone              8886.00             0.187381
# ms_pacman                1386.14             0.162371
# alien                     860.46             0.091691
# qbert                     589.60             0.032029
#
# -tag: gl_aug_uat_hn1_no_dist-
#                 GameScoreAverage  GameScoreNormalized
# game
# kung_fu_master          10310.20             0.447183
# battle_zone             10016.00             0.219826
# ms_pacman                1192.58             0.133239
# alien                     906.26             0.098329
# qbert                     700.55             0.040377
#
# -tag: byol_aug_l-
#                 GameScoreAverage  GameScoreNormalized
# game
# kung_fu_master          17075.40             0.748156
# battle_zone              8315.00             0.170986
# ms_pacman                1277.52             0.146023
# alien                     700.28             0.068476
# qbert                     663.65             0.037600
#
# -tag: byol_g-
#                 GameScoreAverage  GameScoreNormalized
# game
# kung_fu_master       5622.600000             0.238640
# battle_zone         10070.000000             0.221377
# ms_pacman            1399.800000             0.164427
# alien                1050.066667             0.119171
# qbert                 554.950000             0.029422
#
# -tag: byol_aug_g-
#                 GameScoreAverage  GameScoreNormalized
# game
# kung_fu_master          10783.00             0.468218
# ms_pacman                1278.68             0.146197
# alien                     833.78             0.087824
# battle_zone              4500.00             0.061446
# qbert                     735.35             0.042995
#
# UAT
#                 GameScoreAverage  GameScoreNormalized
# game
# kung_fu_master           8557.20             0.369195
# battle_zone              8708.00             0.182270
# ms_pacman                1016.46             0.106732
# alien                     758.48             0.076911
# qbert                     802.75             0.048066
#
# UAT no-dist pri aug
#                 GameScoreAverage  GameScoreNormalized
# game
# kung_fu_master         12462.600             0.542940
# battle_zone             7068.000             0.135181
# ms_pacman               1073.500             0.115317
# alien                    869.275             0.092969
# qbert                    710.450             0.041122
#
# Our DRQ
#                 GameScoreAverage  GameScoreNormalized
# game
# kung_fu_master          10775.60             0.467888
# battle_zone              7622.00             0.151088
# ms_pacman                1133.22             0.124305
# alien                     809.06             0.084242
# qbert                     715.45             0.041498
#
# drq
#                 GameScoreAverage  GameScoreNormalized
# game
# battle_zone         13520.618932             0.320454
# kung_fu_master       7106.436288             0.304653
# ms_pacman            1065.595110             0.114127
# alien                 761.433984             0.077339
# qbert                1100.915308             0.070499

# %%
games_dfs[6]
# Out:
#                  Tags   Runtime  Sweep  agent.eps_eval  agent.eps_final  \
# game
# alien             NaN  15171.80    NaN             NaN              NaN
# amidar            NaN  13594.00    NaN             NaN              NaN
# assault           NaN  11507.60    NaN             NaN              NaN
# asterix           NaN   8334.00    NaN             NaN              NaN
# bank_heist        NaN  11831.75    NaN             NaN              NaN
# battle_zone       NaN  14294.00    NaN             NaN              NaN
# boxing            NaN  12216.00    NaN             NaN              NaN
# breakout          NaN  15574.00    NaN             NaN              NaN
# chopper_command   NaN  22221.80    NaN             NaN              NaN
# crazy_climber     NaN  14582.60    NaN             NaN              NaN
# demon_attack      NaN  13919.80    NaN             NaN              NaN
# freeway           NaN  14004.50    NaN             NaN              NaN
# frostbite         NaN  11127.25    NaN             NaN              NaN
# gopher            NaN   9275.40    NaN             NaN              NaN
# hero              NaN  11642.00    NaN             NaN              NaN
# jamesbond         NaN  13847.00    NaN             NaN              NaN
# kangaroo          NaN  10560.75    NaN             NaN              NaN
# krull             NaN  14644.60    NaN             NaN              NaN
# kung_fu_master    NaN  15490.60    NaN             NaN              NaN
# ms_pacman         NaN  14045.00    NaN             NaN              NaN
# pong              NaN  10513.80    NaN             NaN              NaN
# private_eye       NaN  13940.00    NaN             NaN              NaN
# qbert             NaN  10277.40    NaN             NaN              NaN
# road_runner       NaN  12859.60    NaN             NaN              NaN
# seaquest          NaN  12499.20    NaN             NaN              NaN
# up_n_down         NaN  12211.20    NaN             NaN              NaN
#
#                  agent.eps_init  algo.amortization_decay_constant  \
# game
# alien                       NaN                               NaN
# amidar                      NaN                               NaN
# assault                     NaN                               NaN
# asterix                     NaN                               NaN
# bank_heist                  NaN                               NaN
# battle_zone                 NaN                               NaN
# boxing                      NaN                               NaN
# breakout                    NaN                               NaN
# chopper_command             NaN                               NaN
# crazy_climber               NaN                               NaN
# demon_attack                NaN                               NaN
# freeway                     NaN                               NaN
# frostbite                   NaN                               NaN
# gopher                      NaN                               NaN
# hero                        NaN                               NaN
# jamesbond                   NaN                               NaN
# kangaroo                    NaN                               NaN
# krull                       NaN                               NaN
# kung_fu_master              NaN                               NaN
# ms_pacman                   NaN                               NaN
# pong                        NaN                               NaN
# private_eye                 NaN                               NaN
# qbert                       NaN                               NaN
# road_runner                 NaN                               NaN
# seaquest                    NaN                               NaN
# up_n_down                   NaN                               NaN
#
#                  algo.amortization_loss_weight  algo.batch_size  \
# game
# alien                                      NaN             32.0
# amidar                                     NaN             32.0
# assault                                    NaN             32.0
# asterix                                    NaN             32.0
# bank_heist                                 NaN             32.0
# battle_zone                                NaN             32.0
# boxing                                     NaN             32.0
# breakout                                   NaN             32.0
# chopper_command                            NaN             32.0
# crazy_climber                              NaN             32.0
# demon_attack                               NaN             32.0
# freeway                                    NaN             32.0
# frostbite                                  NaN             32.0
# gopher                                     NaN             32.0
# hero                                       NaN             32.0
# jamesbond                                  NaN             32.0
# kangaroo                                   NaN             32.0
# krull                                      NaN             32.0
# kung_fu_master                             NaN             32.0
# ms_pacman                                  NaN             32.0
# pong                                       NaN             32.0
# private_eye                                NaN             32.0
# qbert                                      NaN             32.0
# road_runner                                NaN             32.0
# seaquest                                   NaN             32.0
# up_n_down                                  NaN             32.0
#
#                  algo.clip_grad_norm     ...       lossStd  modelGradNorm  \
# game                                     ...
# alien                           10.0     ...           NaN            0.0
# amidar                          10.0     ...           NaN            0.0
# assault                         10.0     ...           NaN            0.0
# asterix                         10.0     ...           NaN            0.0
# bank_heist                      10.0     ...           NaN            0.0
# battle_zone                     10.0     ...           NaN            0.0
# boxing                          10.0     ...           NaN            0.0
# breakout                        10.0     ...           NaN            0.0
# chopper_command                 10.0     ...           NaN            0.0
# crazy_climber                   10.0     ...           NaN            0.0
# demon_attack                    10.0     ...           NaN            0.0
# freeway                         10.0     ...           NaN            0.0
# frostbite                       10.0     ...           NaN            0.0
# gopher                          10.0     ...           NaN            0.0
# hero                            10.0     ...           NaN            0.0
# jamesbond                       10.0     ...           NaN            0.0
# kangaroo                        10.0     ...           NaN            0.0
# krull                           10.0     ...           NaN            0.0
# kung_fu_master                  10.0     ...           NaN            0.0
# ms_pacman                       10.0     ...           NaN            0.0
# pong                            10.0     ...           NaN            0.0
# private_eye                     10.0     ...           NaN            0.0
# qbert                           10.0     ...           NaN            0.0
# road_runner                     10.0     ...           NaN            0.0
# seaquest                        10.0     ...           NaN            0.0
# up_n_down                       10.0     ...           NaN            0.0
#
#                  modelLoss  modelRLLoss  tdAbsErr  tdAbsErrAverage  \
# game
# alien                  NaN          0.0       NaN              NaN
# amidar                 NaN          0.0       NaN              NaN
# assault                NaN          0.0       NaN              NaN
# asterix                NaN          0.0       NaN              NaN
# bank_heist             NaN          0.0       NaN              NaN
# battle_zone            NaN          0.0       NaN              NaN
# boxing                 NaN          0.0       NaN              NaN
# breakout               NaN          0.0       NaN              NaN
# chopper_command        NaN          0.0       NaN              NaN
# crazy_climber          NaN          0.0       NaN              NaN
# demon_attack           NaN          0.0       NaN              NaN
# freeway                NaN          0.0       NaN              NaN
# frostbite              NaN          0.0       NaN              NaN
# gopher                 NaN          0.0       NaN              NaN
# hero                   NaN          0.0       NaN              NaN
# jamesbond              NaN          0.0       NaN              NaN
# kangaroo               NaN          0.0       NaN              NaN
# krull                  NaN          0.0       NaN              NaN
# kung_fu_master         NaN          0.0       NaN              NaN
# ms_pacman              NaN          0.0       NaN              NaN
# pong                   NaN          0.0       NaN              NaN
# private_eye            NaN          0.0       NaN              NaN
# qbert                  NaN          0.0       NaN              NaN
# road_runner            NaN          0.0       NaN              NaN
# seaquest               NaN          0.0       NaN              NaN
# up_n_down              NaN          0.0       NaN              NaN
#
#                  tdAbsErrMax  tdAbsErrMedian  tdAbsErrMin  tdAbsErrStd
# game
# alien                    NaN             NaN          NaN          NaN
# amidar                   NaN             NaN          NaN          NaN
# assault                  NaN             NaN          NaN          NaN
# asterix                  NaN             NaN          NaN          NaN
# bank_heist               NaN             NaN          NaN          NaN
# battle_zone              NaN             NaN          NaN          NaN
# boxing                   NaN             NaN          NaN          NaN
# breakout                 NaN             NaN          NaN          NaN
# chopper_command          NaN             NaN          NaN          NaN
# crazy_climber            NaN             NaN          NaN          NaN
# demon_attack             NaN             NaN          NaN          NaN
# freeway                  NaN             NaN          NaN          NaN
# frostbite                NaN             NaN          NaN          NaN
# gopher                   NaN             NaN          NaN          NaN
# hero                     NaN             NaN          NaN          NaN
# jamesbond                NaN             NaN          NaN          NaN
# kangaroo                 NaN             NaN          NaN          NaN
# krull                    NaN             NaN          NaN          NaN
# kung_fu_master           NaN             NaN          NaN          NaN
# ms_pacman                NaN             NaN          NaN          NaN
# pong                     NaN             NaN          NaN          NaN
# private_eye              NaN             NaN          NaN          NaN
# qbert                    NaN             NaN          NaN          NaN
# road_runner              NaN             NaN          NaN          NaN
# seaquest                 NaN             NaN          NaN          NaN
# up_n_down                NaN             NaN          NaN          NaN
#
# [26 rows x 206 columns]

# %%
df = byol_sweeps[0]

for game in set(list(df.game)):
    game_df = df[df.game == game]
    
    sns.jointplot(game_df.ModelNCELoss,
                  game_df.GameScoreNormalized,
                  kind="reg", stat_func=r2)
    plt.title(game)
    plt.show()
# Out:
# C:\Users\user1\AppData\Local\conda\conda\envs\pytorch\lib\site-packages\seaborn\axisgrid.py:1847: UserWarning: JointGrid annotation is deprecated and will be removed in a future release.
#   warnings.warn(UserWarning(msg))
# C:\Users\user1\AppData\Local\conda\conda\envs\pytorch\lib\site-packages\seaborn\axisgrid.py:1847: UserWarning: JointGrid annotation is deprecated and will be removed in a future release.
#   warnings.warn(UserWarning(msg))
# C:\Users\user1\AppData\Local\conda\conda\envs\pytorch\lib\site-packages\seaborn\axisgrid.py:1847: UserWarning: JointGrid annotation is deprecated and will be removed in a future release.
#   warnings.warn(UserWarning(msg))
# C:\Users\user1\AppData\Local\conda\conda\envs\pytorch\lib\site-packages\seaborn\axisgrid.py:1847: UserWarning: JointGrid annotation is deprecated and will be removed in a future release.
#   warnings.warn(UserWarning(msg))
# C:\Users\user1\AppData\Local\conda\conda\envs\pytorch\lib\site-packages\seaborn\axisgrid.py:1847: UserWarning: JointGrid annotation is deprecated and will be removed in a future release.
#   warnings.warn(UserWarning(msg))
# C:\Users\user1\AppData\Local\conda\conda\envs\pytorch\lib\site-packages\seaborn\axisgrid.py:1847: UserWarning: JointGrid annotation is deprecated and will be removed in a future release.
#   warnings.warn(UserWarning(msg))
# C:\Users\user1\AppData\Local\conda\conda\envs\pytorch\lib\site-packages\seaborn\axisgrid.py:1847: UserWarning: JointGrid annotation is deprecated and will be removed in a future release.
#   warnings.warn(UserWarning(msg))
# C:\Users\user1\AppData\Local\conda\conda\envs\pytorch\lib\site-packages\seaborn\axisgrid.py:1847: UserWarning: JointGrid annotation is deprecated and will be removed in a future release.
#   warnings.warn(UserWarning(msg))
